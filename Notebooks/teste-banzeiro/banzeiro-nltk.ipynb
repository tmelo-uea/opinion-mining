# %% [markdown]
# # Parte 1
#
# ## Imports
#
# - **numpy**:
# - **pandas**:
# - **nltk**: Para POS tagging, tokenização de sentenças e demais itens inerentes a NLP
# - **emoji**: Para converter emojis no texto para suas respectivas descriçrões
# - _emot_: Considerar o uso para extrair emojis e emoticons do texto
# - **re**: Para encontrar padrões por meio de expressões regulares

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import mac_morpho
import emoji
import re

# %% [markdown]
# ## Leitura dos dados
#
# Lendo os dados do arquivo **banzeiro.json** em duas listas de objetos, que serão representados por `dicts`. Uma lista guardará os dados com os emojis substituídos pelas suas respectivas descrições e a outra, o conteúdo original.

# %%
posts = pd.read_json("banzeiro.json")
posts.head()
# Out:
#                                         key                  datetime  \
# 0  https://www.instagram.com/p/B2mMB_OHbfI/ 2019-09-19 14:47:48+00:00
# 1  https://www.instagram.com/p/B2ef0osHDik/ 2019-09-16 15:06:49+00:00
# 2  https://www.instagram.com/p/B2ZXEGSn1di/ 2019-09-14 15:14:05+00:00
# 3  https://www.instagram.com/p/B2UpaJ5HLWg/ 2019-09-12 19:23:34+00:00
# 4  https://www.instagram.com/p/B2PCM4Qn9mD/ 2019-09-10 14:59:22+00:00
#
#                                             img_urls  \
# 0  [https://z-p42-instagram.fpll2-1.fna.fbcdn.net...
# 1  [https://z-p42-instagram.fpll2-1.fna.fbcdn.net...
# 2  [https://z-p42-instagram.fpll2-1.fna.fbcdn.net...
# 3                                                 []
# 4  [https://z-p42-instagram.fpll2-1.fna.fbcdn.net...
#
#                                              caption  \
# 0  Já provou os nossos Chás Gelados?\nAs três com...
# 1  Uma das entradas exclusivas do Banzeiro Manaus...
# 2  “Todos os dias penso no compromisso que tenho ...
# 3  Felipe Schaedler, Cidadão Amazonense!\n\nAssis...
# 4  Tanga verde de folhas, corpo claro de Cacau e ...
#
#                                             comments
# 0  [{'author': 'audreycaminha', 'comment': 'Delic...
# 1  [{'author': 'karenmabel', 'comment': 'é sensac...
# 2  [{'author': '59cmlc', 'comment': 'Estive no Ba...
# 3  [{'author': 'ricfeitoza', 'comment': '👏🏽👏🏽👏🏽👏🏽...
# 4  [{'author': 'ginapsic', 'comment': 'Delicia'},...

# %% [markdown]
# Verificando a estrutura dos dados, é possível perceber que existem colunas que não contém texto excrito por usuários, que uma publicação não possui legenda (`caption`) e que nem todas as instâncias possuem um vetor de comentários a ser processado (`comments`).

# %%
posts.count()
# Out:
# key         778
# datetime    778
# img_urls    778
# caption     777
# comments    606
# dtype: int64

# %% [markdown]
# # Parte 2
#
# ## Limpeza de dados
#
# Algumas operações de limpeza dos dados deverão ser realizadas, considerando os seguintes pontos:
#
# - Algumas colunas não são relevantes no processamento de texto
# - Comentários que apenas mencionam outros usuários não expressam uma opinião
# - Publicações sem legenda não deixam claro a que se endereça a opinião
# - Publicações sem comentários não possuem opiniões a serem mineradas

# %% [markdown]
# ### Removendo colunas sem importância

# %%
posts = posts.drop(["key", "datetime", "img_urls"], axis=1)

# %%
posts
# Out:
#                                                caption  \
# 0    Já provou os nossos Chás Gelados?\nAs três com...
# 1    Uma das entradas exclusivas do Banzeiro Manaus...
# 2    “Todos os dias penso no compromisso que tenho ...
# 3    Felipe Schaedler, Cidadão Amazonense!\n\nAssis...
# 4    Tanga verde de folhas, corpo claro de Cacau e ...
# ..                                                 ...
# 773  Totalmente diferente de tudo o que você já pro...
# 774  Pôr do sol em São Gabriel da Cachoeira, por Fe...
# 775  Viaje com os sabores e combinações exóticas do...
# 776  Petit gateau amazônico.\nVenha saborear essa m...
# 777  HOJE TEM: Carpaccio de Palmito de Pupunha com ...
#
#                                               comments
# 0    [{'author': 'audreycaminha', 'comment': 'Delic...
# 1    [{'author': 'karenmabel', 'comment': 'é sensac...
# 2    [{'author': '59cmlc', 'comment': 'Estive no Ba...
# 3    [{'author': 'ricfeitoza', 'comment': '👏🏽👏🏽👏🏽👏🏽...
# 4    [{'author': 'ginapsic', 'comment': 'Delicia'},...
# ..                                                 ...
# 773  [{'author': 'gilson_monteiro', 'comment': 'O q...
# 774                                                NaN
# 775                                                NaN
# 776  [{'author': 'victorer83', 'comment': '@marinay...
# 777                                                NaN
#
# [778 rows x 2 columns]

# %% [markdown]
# ### Removendo linhas onde caption ou comments são nulos

# %%
posts = posts.dropna()

# %%
posts
# Out:
#                                                caption  \
# 0    Já provou os nossos Chás Gelados?\nAs três com...
# 1    Uma das entradas exclusivas do Banzeiro Manaus...
# 2    “Todos os dias penso no compromisso que tenho ...
# 3    Felipe Schaedler, Cidadão Amazonense!\n\nAssis...
# 4    Tanga verde de folhas, corpo claro de Cacau e ...
# ..                                                 ...
# 765  Desbrave novos sabores, embale seu paladar e d...
# 767  Pastel de pato. Deliciosamente incomparável. U...
# 771  O chef Felipe Schaedler foi convidado para par...
# 773  Totalmente diferente de tudo o que você já pro...
# 776  Petit gateau amazônico.\nVenha saborear essa m...
#
#                                               comments
# 0    [{'author': 'audreycaminha', 'comment': 'Delic...
# 1    [{'author': 'karenmabel', 'comment': 'é sensac...
# 2    [{'author': '59cmlc', 'comment': 'Estive no Ba...
# 3    [{'author': 'ricfeitoza', 'comment': '👏🏽👏🏽👏🏽👏🏽...
# 4    [{'author': 'ginapsic', 'comment': 'Delicia'},...
# ..                                                 ...
# 765  [{'author': 'mellothz', 'comment': 'Estive no ...
# 767  [{'author': 'chriscalderaro', 'comment': 'Eu a...
# 771  [{'author': 'thiagosuico', 'comment': '@felipe...
# 773  [{'author': 'gilson_monteiro', 'comment': 'O q...
# 776  [{'author': 'victorer83', 'comment': '@marinay...
#
# [606 rows x 2 columns]

# %% [markdown]
# ### Removendo comentários que somente mencionam outros usuários
#
# Fazendo o uso de Expressão Regular, qualquer comentário que contenha apenas nomes de outros usuários, com objetivo único de mencioná-los na publicação, será removido. Linhas que eventualmente fiquem sem comentários serão descartadas.

# %%
for index, row in posts.iterrows():
    for comment in row["comments"]:
        if re.search("^(@[a-z0-9_.]*\s*)+$", comment["comment"]):
            posts.at[index, "comments"].remove(comment)
posts = posts.dropna()

# %%
posts
# Out:
#                                                caption  \
# 0    Já provou os nossos Chás Gelados?\nAs três com...
# 1    Uma das entradas exclusivas do Banzeiro Manaus...
# 2    “Todos os dias penso no compromisso que tenho ...
# 3    Felipe Schaedler, Cidadão Amazonense!\n\nAssis...
# 4    Tanga verde de folhas, corpo claro de Cacau e ...
# ..                                                 ...
# 765  Desbrave novos sabores, embale seu paladar e d...
# 767  Pastel de pato. Deliciosamente incomparável. U...
# 771  O chef Felipe Schaedler foi convidado para par...
# 773  Totalmente diferente de tudo o que você já pro...
# 776  Petit gateau amazônico.\nVenha saborear essa m...
#
#                                               comments
# 0    [{'author': 'audreycaminha', 'comment': 'Delic...
# 1    [{'author': 'karenmabel', 'comment': 'é sensac...
# 2    [{'author': '59cmlc', 'comment': 'Estive no Ba...
# 3    [{'author': 'ricfeitoza', 'comment': '👏🏽👏🏽👏🏽👏🏽...
# 4    [{'author': 'ginapsic', 'comment': 'Delicia'},...
# ..                                                 ...
# 765  [{'author': 'mellothz', 'comment': 'Estive no ...
# 767  [{'author': 'chriscalderaro', 'comment': 'Eu a...
# 771  [{'author': 'thiagosuico', 'comment': '@felipe...
# 773  [{'author': 'gilson_monteiro', 'comment': 'O q...
# 776  [{'author': 'victorer83', 'comment': '@marinay...
#
# [606 rows x 2 columns]

# %% [markdown]
# # Parte 3
#
# ## Convertendo o dataframe para dict
#
# Com a parte de limpeza dos dados finalizada e antes do processamento realizado pelo NLTK, os dados serão representados em forma de **dict**.

# %%
posts = posts.to_dict('records')

# %% [markdown]
# ## Tokenizando sentenças e Strings
#
# Fazendo o uso do **nltk**, serão tokenizadas as sentenças e palavras do dataset. As sentenças serão quebradas com o tokenizador **Punkt** treinado para o Português, e as palavras, quebrando nos espaços em branco.

# %%
nltk.download("punkt")
sent_tokenizer=nltk.data.load('tokenizers/punkt/portuguese.pickle')
# Out:
# [nltk_data] Downloading package punkt to /home/miguel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### POS Tagging
#
# A marcação de _Part-of-Speech_ será feita com _taggers_ do NLTK treinados com o _corpus_ **Mac Morpho** de notícias do jornal Folha de S. Paulo de 1994. Para manter o código mais limpo, a tokenização e as marcações ocorrerão em conjunto.

# %%
tsents = mac_morpho.tagged_sents()

# %% [markdown]
# - *noun_tagger* é o tagger default, se nenhum outro resolve, ele assume que é um substantivo
# - *unigram_tagger* é um tagger para unigramas, baseado na maior frequência de tags encontrada nos corpus de treino
# - *bigram_tagger* é um tagger para bigramas que avalia a palavra levando em consideração a palavra anterior, afim de resolver ambiguidades

# %%
noun_tagger = nltk.DefaultTagger('N')
unigram_tagger = nltk.UnigramTagger(tsents, backoff=noun_tagger)
bigram_tagger = nltk.BigramTagger(tsents, backoff=unigram_tagger)

# %%
for p in posts:
    sentences = sent_tokenizer.tokenize(p["caption"])
    print("Caption: " )
    p["caption"] = [bigram_tagger.tag(nltk.word_tokenize(sentence)) for sentence in sentences]
    print(p["caption"], "\n\n")
    for c in p["comments"]:
        print("Comment: " )
        sentences = sent_tokenizer.tokenize(c["comment"])
        c["comment"] = [bigram_tagger.tag(nltk.word_tokenize(sentence)) for sentence in sentences]
        print(c["comment"], "\n\n")
# Out:
# Caption:
# [[('Já', 'ADV'), ('provou', 'V'), ('os', 'ART'), ('nossos', 'PROADJ'), ('Chás', 'N'), ('Gelados', 'N'), ('?', '?')], [('As', 'ART'), ('três', 'NUM'), ('combinações', 'N'), ('que', 'PRO-KS-REL'), ('vem', 'V'), ('chamando', 'V'), ('a', 'ART'), ('atenção', 'N'), ('dos', 'N'), ('nossos', 'PROADJ'), ('clientes', 'N'), ('que', 'PRO-KS-REL'), ('optam', 'N'), ('por', 'PREP'), ('uma', 'ART'), ('opção', 'N'), ('refrescante', 'N'), ('e', 'KC'), ('não', 'ADV'), ('alcoólica', 'ADJ'), (':', ':'), ('Hibisco', 'N'), ('com', 'PREP'), ('Abacaxi', 'N'), ('de', 'PREP'), ('Manaus', 'NPROP'), (',', ','), ('Limão', 'NPROP'), ('com', 'PREP'), ('Alecrim', 'N'), ('e', 'KC'), ('Maracujá', 'N'), ('com', 'PREP'), ('Cumaru', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('Deliciosos', 'N')]]
#
#
# Caption:
# [[('Uma', 'ART'), ('das', 'NPROP'), ('entradas', 'N'), ('exclusivas', 'ADJ'), ('do', 'KS'), ('Banzeiro', 'N'), ('Manaus', 'NPROP'), ('.', 'NPROP')], [('Experimente', 'V|+'), ('o', 'PROPESS'), ('nosso', 'PROADJ'), ('Tacacá', 'N'), ('assado', 'PCP'), ('na', 'ADV'), ('brasa', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('é', 'V'), ('sensacional', 'ADJ'), ('!', '!')]]
#
#
# Comment:
# [[('@', 'N'), ('karenmabel', 'N'), ('🙏🏼♥️', 'N')]]
#
#
# Comment:
# [[('Precisa', 'VAUX'), ('trazer', 'V'), ('pro', 'N'), ('@', 'N'), ('banzeirosp', 'N'), ('@', 'N'), ('felipeschaedler_', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('fernandacoutoo', 'N')]]
#
#
# Comment:
# [[('Quanto', 'PREP|+'), ('a', 'ART'), ('cuia', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('Sonhando', 'N'), ('com', 'PREP'), ('essa', 'PROADJ'), ('maravilha', 'N'), ('😍', 'N')]]
#
#
# Caption:
# [[('“', 'N'), ('Todos', 'PROADJ'), ('os', 'ART'), ('dias', 'N'), ('penso', 'V'), ('no', 'PREP|+'), ('compromisso', 'N'), ('que', 'PRO-KS-REL'), ('tenho', 'V'), ('com', 'PREP'), ('esse', 'PROADJ'), ('estado', 'N'), ('e', 'KC'), ('como', 'KC'), ('posso', 'VAUX'), ('retribuir', 'N'), ('tudo', 'PROSUB'), ('que', 'PRO-KS-REL'), ('conquistei', 'N'), ('aqui', 'ADV'), ('.', '.')], [('Uma', 'ART'), ('dívida', 'N'), ('moral', 'ADJ'), ('que', 'PRO-KS-REL'), ('me', 'PROPESS'), ('motivou', 'V'), ('à', 'ADV'), ('abertura', 'N'), ('do', 'KS'), ('Banzeiro', 'N'), ('SP', 'NPROP'), ('.', 'NPROP')], [('São', 'V'), ('Paulo', 'NPROP'), ('não', 'ADV'), ('é', 'V'), ('vaidade', 'N'), (',', ','), ('não', 'ADV'), ('é', 'V'), ('fama', 'N'), ('e', 'KC'), ('também', 'PDEN'), ('não', 'ADV'), ('é', 'V'), ('por', 'PREP'), ('dinheiro', 'N'), ('.', '.')], [('É', 'V'), ('por', 'PREP'), ('uma', 'ART'), ('questão', 'N'), ('moral', 'ADJ'), ('que', 'PRO-KS-REL'), ('tenho', 'V'), ('com', 'PREP'), ('o', 'ART'), ('Amazonas', 'NPROP'), ('!', '!')], [('Quando', 'KS'), ('abrimos', 'N'), ('o', 'ART'), ('Banzeiro', 'N'), ('em', 'PREP|+'), ('Manaus', 'NPROP'), (',', ','), ('meu', 'PROADJ'), ('sonho', 'N'), ('era', 'V'), ('dar', 'V'), ('destaque', 'N'), ('para', 'PREP'), ('a', 'ART'), ('cozinha', 'N'), ('amazonense', 'N'), ('.', '.')], [('Passado', 'N'), ('isso', 'PROSUB'), (',', ','), ('já', 'ADV'), ('levei', 'V'), ('a', 'ART'), ('nossa', 'PROADJ'), ('banzeira', 'N'), ('para', 'PREP'), ('cinco', 'NUM'), ('países', 'N'), ('em', 'PREP|+'), ('três', 'NUM'), ('continentes', 'N'), ('diferentes', 'ADJ'), ('.', '.')], [('Mesmo', 'PDEN'), ('com', 'PREP'), ('tal', 'PROADJ'), ('aparente', 'ADJ'), ('sucesso', 'N'), (',', ','), ('isso', 'PROSUB'), ('nunca', 'ADV'), ('me', 'PROPESS'), ('satisfez', 'N'), ('.', '.')], [('Hoje', 'ADV'), ('eu', 'PROPESS'), ('entendo', 'V'), ('que', 'KS'), ('não', 'ADV'), ('são', 'V'), ('os', 'ART'), ('outros', 'PROADJ'), ('países', 'N'), ('do', 'KS'), ('mundo', 'N'), ('que', 'PRO-KS-REL'), ('precisam', 'V'), ('conhecer', 'V'), ('o', 'ART'), ('Amazonas', 'NPROP'), ('.', 'NPROP')], [('São', 'V'), ('os', 'ART'), ('próprios', 'PROADJ'), ('brasileiros', 'N'), ('.', '.')], [('O', 'ART'), ('Brasil', 'NPROP'), ('precisa', 'V'), ('descobrir', 'V'), ('o', 'ART'), ('Brasil', 'NPROP'), ('!', '!'), ('”', 'N')]]
#
#
# Comment:
# [[('Estive', 'V'), ('no', 'PREP|+'), ('Banxeiro', 'N'), ('Manaus', 'NPROP'), ('e', 'KC'), ('posso', 'VAUX'), ('garantir', 'V'), ('que', 'KS'), ('é', 'V'), ('um', 'ART'), ('caso', 'N'), ('de', 'PREP'), ('amor', 'N'), ('a', 'PREP|+'), ('primeira', 'ADJ'), ('garfada❣', 'N')]]
#
#
# Comment:
# [[('👏👏👏', 'N')]]
#
#
# Comment:
# [[('👏👏👏👏👏', 'N')]]
#
#
# Comment:
# [[('👏👏👏', 'N'), ('Hj', 'N'), ('irei', 'N'), ('conhecer', 'V'), ('essa', 'PROADJ'), ('culinária', 'N'), ('tão', 'ADV'), ('falada', 'PCP'), ('.', '.')]]
#
#
# Comment:
# [[('Genial', 'N'), ('e', 'KC'), ('super', 'ADJ'), ('verdadeiro', 'ADJ'), ('!', '!')], [('Fui', 'V'), ('nas', 'NPROP'), ('últimas', 'ADJ'), ('férias', 'N'), ('para', 'PREP'), ('a', 'ART'), ('Amazônia', 'NPROP'), ('e', 'KC'), ('amei', 'V'), ('tudo', 'PROSUB'), (',', ','), ('sem', 'PREP'), ('exceção', 'N'), ('.', '.')], [('Melhor', 'ADJ'), ('viagem', 'N'), ('da', 'N'), ('vida', 'N'), ('!', '!'), ('!', '!'), ('!', '!'), ('!', '!')], [('Agora', 'ADV'), ('saber', 'V'), ('que', 'KS'), ('vcs', 'N'), ('estão', 'V'), ('aqui', 'ADV'), ('em', 'PREP|+'), ('SP', 'NPROP'), ('perto', 'PREP|+'), ('de', 'PREP|+'), ('nos', 'PROPESS'), (',', ','), ('nos', 'PROPESS'), ('possibilita', 'V'), ('apresentar', 'V'), ('essa', 'PROADJ'), ('linda', 'ADJ'), ('gastronomia', 'N'), ('aos', 'ADV'), ('nossos', 'PROADJ'), ('amigos', 'N'), ('e', 'KC'), ('incentiva-lós', 'N'), ('a', 'PREP|+'), ('conhecer', 'V'), ('essas', 'PROADJ'), ('belezas', 'N'), ('que', 'PRO-KS-REL'), ('nosso', 'PROADJ'), ('país', 'N'), ('tem', 'V'), ('.', '.')], [('Só', 'PDEN'), ('adaptaria', 'N'), ('sua', 'PROADJ'), ('frase', 'N'), ('para', 'PREP'), ('“', 'N'), ('O', 'ART'), ('Brasil', 'NPROP'), ('precisa', 'V'), ('e', 'KC'), ('merece', 'V'), ('descobrir', 'V'), ('o', 'ART'), ('Brasil', 'NPROP'), ('”', 'N'), ('parabéns', 'ADJ'), ('pelo', 'PDEN'), ('lindo', 'ADJ'), ('trabalho', 'N'), ('!', '!'), ('!', '!'), ('!', '!')], [('!', '!'), ('🙏🏻😀', 'N')]]
#
#
# Comment:
# [[('Vocês', 'PROPESS'), ('arrebentaaaaaaaaam', 'N'), ('@', 'N'), ('felipeschaedler_', 'N'), ('@', 'N'), ('thiagoschaedler', 'N'), ('@', 'N'), ('nelsaschaedler', 'N'), ('@', 'N'), ('ivarschaedler', 'N'), ('❤️❤️❤️❤️', 'N')]]
#
#
# Comment:
# [[('Razô', 'N'), ('😍👏🏼👏🏼👏🏼👏🏼👏🏼', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('restaurantebanzeiro', 'N'), ('Muito', 'ADV'), ('legal', 'ADJ'), ('!', '!')], [('Suas', 'PROADJ'), ('palavras', 'N'), ('faz', 'V'), ('sentido', 'N'), (',', ','), ('nós', 'PROPESS'), ('brasileiros', 'ADJ'), ('precisamos', 'V'), ('valorizar', 'V'), ('mais', 'ADV'), ('e', 'KC'), ('mais', 'ADV'), ('❤️👍', 'N')]]
#
#
# Comment:
# [[('Sucesso👌🏻', 'N')]]
#
#
# Comment:
# [[('❤️😍', 'N')]]
#
#
# Comment:
# [[('Oi', 'IN'), ('Felipe', 'NPROP'), ('.', 'NPROP')], [('Sou', 'V'), ('Mary', 'NPROP'), ('do', 'NPROP'), ('Beth', 'NPROP'), ('balanço', 'N'), (',', ','), ('gostaria', 'V'), ('de', 'PREP'), ('fazer', 'V'), ('uma', 'ART'), ('reserva', 'N'), ('pro', 'N'), ('dia', 'N'), ('27/09', 'N'), ('após', 'PREP'), ('8h', 'N|HOR'), ('.', '.')], [('Para', 'PREP'), ('6', 'NUM'), ('pessoas', 'N'), ('.', '.')], [('Pode', 'VAUX'), ('ser', 'VAUX'), ('?', '?')]]
#
#
# Comment:
# [[('Bem', 'ADV'), ('isso', 'PROSUB'), ('Felipe', 'NPROP'), ('!', '!')], [('Muito', 'ADV'), ('feliz', 'ADJ'), ('com', 'PREP'), ('o', 'ART'), ('seu', 'PROADJ'), ('compromisso', 'N'), ('com', 'PREP'), ('a', 'ART'), ('tradição', 'N'), ('amazonense.👏🏻👏🏻👏🏻', 'N')]]
#
#
# Comment:
# [[('👏👏👏👏Show', 'N'), ('!', '!'), ('!', '!')], [('!', '!')]]
#
#
# Comment:
# [[('Verdade', 'NPROP'), ('nosso', 'NPROP'), ('Brasil', 'NPROP'), ('e', 'KC'), ('nosso', 'PROADJ'), ('Amazonas', 'NPROP'), ('é', 'V'), ('lindíssimo', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('Por', 'PREP'), ('isso', 'PROSUB'), ('que', 'PRO-KS-REL'), ('minha', 'PROADJ'), ('tese', 'N'), ('de', 'PREP'), ('doutorado', 'N'), ('será', 'VAUX'), ('sobre', 'PREP'), ('a', 'ART'), ('Gastronomia', 'N'), ('do', 'KS'), ('Amazonas', 'NPROP'), ('!', '!'), ('!', '!'), ('!', '!'), ('!', '!')], [('A', 'ART'), ('melhor', 'ADJ'), ('do', 'KS'), ('mundo', 'N'), ('.', '.')], [('👊', 'N')]]
#
#
# Comment:
# [[('👏👏👏', 'N')]]
#
#
# Comment:
# [[('👏👏👏', 'N')]]
#
#
# Comment:
# [[('👏🏽👏🏽👏🏽👏🏽Sucesso', 'N'), ('!', '!'), ('!', '!')], [('!', '!')]]
#
#
# Comment:
# [[('👏👏👏👏', 'N'), ('Pensamento', 'NPROP'), ('positivo', 'ADJ'), ('que', 'PRO-KS-REL'), ('faz', 'V'), ('bem', 'ADV'), ('ao', 'PREP'), ('coração', 'N'), ('!', '!')], [('Pro', 'NPROP'), ('alto', 'ADJ'), ('e', 'KC'), ('avante', 'ADV')]]
#
#
# Comment:
# [[('Florianópolis', 'NPROP'), ('precisa', 'V'), ('conhecer', 'V'), ('o', 'ART'), ('Amazonas', 'NPROP'), ('!', '!'), ('!', '!'), ('!', '!')], [('Vem', 'V'), ('Banzeiro', 'N'), ('!', '!'), ('!', '!')], [('!', '!'), ('😍❤️', 'N')]]
#
#
# Comment:
# [[('👏👏', 'N')]]
#
#
# Comment:
# [[('👏🏻👏🏻👏🏻', 'N'), ('Sucesso', 'NPROP')]]
#
#
# Comment:
# [[('Lindas', 'N'), ('palavras', 'N'), (',', ','), ('o', 'ART'), ('Brasil', 'NPROP'), ('precisa', 'V'), ('descobrir', 'V'), ('o', 'ART'), ('Brasil', 'NPROP'), ('...', 'NPROP'), ('verdade', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('Muito', 'ADV'), ('orgulho', 'N'), ('!', '!')], [('Obrigada', 'PCP'), ('por', 'PREP|+'), ('isso', 'PROSUB'), ('!', '!')]]
#
#
# Caption:
# [[('Felipe', 'NPROP'), ('Schaedler', 'N'), (',', ','), ('Cidadão', 'N'), ('Amazonense', 'NPROP'), ('!', '!')], [('Assista', 'N'), ('na', 'ADV'), ('íntegra', 'ADV'), ('o', 'ART'), ('discurso', 'N'), ('do', 'KS'), ('Chef', 'N'), ('Felipe', 'NPROP'), ('Schaedler', 'N'), ('na', 'ADV'), ('entrega', 'N'), ('do', 'KS'), ('título', 'N'), ('de', 'PREP'), ('Cidadão', 'N'), ('Amazonense', 'NPROP'), (',', ','), ('na', 'KS'), ('última', 'ADJ'), ('terça-feira', 'N'), (',', ','), ('dia', 'N'), ('10', 'N|AP'), (',', ','), ('no', 'KC'), ('plenário', 'N'), ('da', 'N'), ('Assembleia', 'N'), ('Legislativa', 'ADJ'), ('do', 'KS'), ('Estado', 'N'), ('do', 'KS'), ('Amazonas', 'NPROP'), ('.', 'NPROP')]]
#
#
# Comment:
# [[('👏🏽👏🏽👏🏽👏🏽', 'N')]]
#
#
# Comment:
# [[('Fantástico', 'NPROP'), ('.', 'NPROP')], [('Merecido', 'N'), ('!', '!')], [('!', '!')]]
#
#
# Comment:
# [[('Parabéns', 'N'), ('Felipe', 'NPROP'), ('!', '!')]]
#
#
# Comment:
# [[('👏🏾👏🏾👏🏾👏🏾👏🏾', 'N')]]
#
#
# Comment:
# [[('Que', 'PROADJ'), ('linda', 'ADJ'), ('história', 'N'), ('e', 'KC'), ('trajetória', 'N'), (',', ','), ('na', 'KS'), ('época', 'N'), ('da', 'N'), ('minha', 'PROADJ'), ('faculdade', 'N'), ('Sempre', 'ADV'), ('ouvia', 'V'), ('falar', 'V'), ('do', 'KS'), ('Felipe', 'NPROP'), ('mas', 'KC'), (',', ','), ('totalmente', 'ADV'), ('diferente', 'ADJ'), ('do', 'KS'), ('que', 'KS'), ('eu', 'PROPESS'), ('ouvi', 'V'), ('no', 'PREP|+'), ('seu', 'PROADJ'), ('discurso', 'N'), (',', ','), ('e', 'KC'), ('essa', 'PROADJ'), ('história', 'N'), ('como', 'PREP'), ('muitas', 'PROADJ'), ('das', 'NPROP'), ('que', 'PRO-KS-REL'), ('nos', 'PROPESS'), ('expira', 'V'), ('a', 'ART'), ('ter', 'V|+'), ('forças', 'N'), ('pra', 'PREP'), ('não', 'ADV'), ('desistir', 'V'), ('dos', 'NPROP'), ('nossos', 'PROADJ'), ('sonhos', 'N'), ('.', '.')], [('Meus', 'PROADJ'), ('parabéns', 'N'), ('muito', 'ADV'), ('merecido', 'PCP'), ('essa', 'PROADJ'), ('homenagem👏👏👏😍', 'N')]]
#
#
# Comment:
# [[('Minhas', 'PROADJ'), ('felicitações', 'N'), ('amigo', 'ADJ'), ('Felipe', 'NPROP'), (',', ','), ('extensivamente', 'N'), ('à', 'PREP|+'), ('sua', 'PROADJ'), ('família', 'N'), ('e', 'KC'), ('ao', 'PREP'), ('seu', 'PROADJ'), ('staff', 'N'), ('.', '.')], [('Pra', 'PREP'), ('você', 'PROPESS'), (',', ','), ('o', 'ART'), ('céu', 'N'), ('é', 'V'), ('o', 'ART'), ('limite.👏👏', 'N')]]
#
#
# Comment:
# [[('Quem', 'PRO-KS'), ('emocionante', 'ADJ'), ('.', '.')], [('Parabéns', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('Eu', 'PROPESS'), ('sabia', 'V'), ('que', 'KS'), ('Itacoatiara', 'N'), ('tinha', 'VAUX'), ('sido', 'PCP'), ('a', 'PREP|+'), ('tua', 'PROADJ'), ('fonte', 'N'), ('de', 'PREP'), ('inspiração', 'N'), ('.', '.')], [('Minha', 'PROADJ'), ('Velha', 'NPROP'), ('Serpa', 'NPROP'), ('é', 'V'), ('abençoada', 'N'), ('mesmo', 'PDEN'), ('🤗😍😂😂😂🙏🙏', 'N'), ('Parabéns', 'N'), ('👏👏', 'N')]]
#
#
# Comment:
# [[('Parabéns', 'N'), ('pela', 'NPROP'), ('conquista', 'V'), ('@', 'N'), ('felipeschaedler_', 'N'), ('.', '.')], [('Assisti', 'V'), ('o', 'ART'), ('episódio', 'N'), ('de', 'PREP'), ('chefs', 'N|EST'), ('brasileiros', 'ADJ'), ('e', 'KC'), ('vi', 'V'), ('como', 'PREP'), ('foi', 'VAUX'), ('o', 'ART'), ('inicio', 'V'), ('de', 'PREP'), ('sua', 'PROADJ'), ('trajetória', 'N'), ('.', '.')], [('Você', 'PROPESS'), ('não', 'ADV'), ('desistiu', 'V'), ('do', 'KS'), ('seu', 'PROADJ'), ('sonho', 'N'), ('.', '.')], [('Inspiração', 'N'), ('para', 'PREP'), ('a', 'ART'), ('vida', 'N'), ('.', '.')], [('Deus', 'NPROP'), ('te', 'PROPESS'), ('abençoe', 'N'), ('❤', 'N')]]
#
#
# Comment:
# [[('Ser', 'V'), ('grato', 'ADJ'), ('um', 'ART'), ('dos', 'NPROP'), ('mais', 'ADV'), ('lindos', 'ADJ'), ('sentimentos', 'N'), ('❣️👏🏽👏🏽👏🏽👏🏽', 'N')]]
#
#
# Comment:
# [[('👏👏👏👏👏👏👏👏', 'N'), ('Que', 'PROADJ'), ('show', 'N|EST'), ('de', 'PREP|+'), ('discurso', 'N'), ('cara', 'ADJ'), ('!', '!')], [('Forte', 'ADJ'), ('abraço', 'N'), ('@', 'N'), ('felipeschaedler_', 'N'), ('merecedor', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('Inspirador', 'N'), ('!', '!'), ('!', '!'), ('!', '!')], [('Parabéns', 'N'), ('@', 'N'), ('felipeschaedler_', 'N'), ('e', 'KC'), ('toda', 'PROADJ'), ('família', 'N'), ('banzeiro', 'N'), ('e', 'KC'), ('Moquem', 'N'), ('👏🏻👏🏻👏🏻👏🏻', 'N')]]
#
#
# Comment:
# [[('Parabéns', 'N'), (',', ','), ('querido', 'PCP'), ('Deus', 'NPROP'), ('abençoe', 'N'), ('abundantemente', 'N'), ('...', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('Parabéns', 'N'), ('Felipe', 'NPROP'), ('.', 'NPROP')], [('Você', 'PROPESS'), ('é', 'V'), ('``', 'N'), ('The', 'NPROP'), ('best', 'N|EST'), ('.', '.'), ("''", 'N')]]
#
#
# Comment:
# [[('Eu', 'PROPESS'), ('amo', 'V'), ('um', 'ART'), ('chef', 'N|EST'), ('♡', 'N')]]
#
#
# Comment:
# [[('👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻', 'N')]]
#
#
# Comment:
# [[('Acompanhamos', 'V'), ('você', 'PROPESS'), ('desde', 'PREP'), ('do', 'PREP'), ('começo', 'N'), ('do', 'KS'), ('seu', 'PROADJ'), ('sucesso', 'N'), ('...', 'N'), ('Parabéns', 'N'), (',', ','), ('você', 'PROPESS'), ('faz', 'V'), ('por', 'PREP'), ('merecer', 'V'), ('.', '.')], [('👏👏👏👏👏👏', 'N')]]
#
#
# Comment:
# [[('Parabéns', 'N'), (',', ','), ('Felipe', 'NPROP'), ('!', '!'), ('!', '!')], [('Trajetória', 'N'), ('de', 'PREP'), ('sucesso', 'N'), ('que', 'PRO-KS-REL'), ('trouxe', 'V'), ('o', 'ART'), ('reconhecimento', 'N'), ('do', 'KS'), ('Estado', 'N'), ('do', 'KS'), ('Amazonas', 'NPROP'), ('.', 'NPROP')], [('Que', 'PROADJ'), ('seu', 'PROADJ'), ('caminho', 'N'), ('continue', 'V'), ('iluminado', 'PCP'), ('.', '.')]]
#
#
# Comment:
# [[('Título', 'N'), ('mais', 'ADV'), ('q', 'N'), ('merecido', 'PCP'), ('!', '!'), ('!', '!'), ('!', '!'), ('!', '!')], [('Discurso', 'NPROP'), ('emocionante', 'ADJ'), ('!', '!'), ('!', '!')], [('!', '!'), ('👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻👏🏻', 'N')]]
#
#
# Comment:
# [[('Parabéns', 'N'), ('Felipe', 'NPROP')]]
#
#
# Comment:
# [[('@', 'N'), ('pantojapedro', 'N'), ('❤️😍', 'N')]]
#
#
# Comment:
# [[('Parabéns', 'N'), ('Felipe', 'NPROP'), ('!', '!')], [('Vc', 'N'), ('merece', 'V'), ('.', '.')], [('❤️🌷', 'N')]]
#
#
# Comment:
# [[('😍😍👏', 'N')]]
#
#
# Caption:
# [[('Tanga', 'N'), ('verde', 'ADJ'), ('de', 'PREP|+'), ('folhas', 'N'), (',', ','), ('corpo', 'N'), ('claro', 'ADJ'), ('de', 'PREP|+'), ('Cacau', 'NPROP'), ('e', 'KC'), ('cabelo', 'N'), ('ruivo', 'N'), ('de', 'PREP'), ('Hibisco', 'N'), ('.', '.')], [('Eis', 'PDEN'), ('o', 'ART'), ('Curupira', 'N'), ('do', 'KS'), ('Banzeiro', 'N'), ('!', '!')], [('•', 'N'), ('📸', 'N'), ('@', 'N'), ('joaoquetirou', 'N')]]
#
#
# Comment:
# [[('Delicia', 'NPROP')]]
#
#
# Comment:
# [[('Parece', 'V'), ('ótimo', 'ADJ'), ('!', '!')], [('👏🏽👏🏽👏🏽', 'N')]]
#
#
# Comment:
# [[('Vou', 'VAUX'), ('provar', 'V'), ('no', 'PREP|+'), ('fim', 'N'), ('de', 'PREP'), ('novembro', 'N'), (',', ','), ('aguarde', 'V'), ('!', '!'), ('👌👌', 'N')]]
#
#
# Caption:
# [[('#', 'N'), ('Repost', 'N'), ('@', 'N'), ('felipeschaedler_', 'N'), ('・・・', 'N'), ('“', 'N'), ('O', 'ART'), ('Amazonas', 'NPROP'), ('é', 'V'), ('a', 'ART'), ('minha', 'PROADJ'), ('vida', 'N'), ('”', 'N'), ('e', 'KC'), ('é', 'V'), ('assim', 'ADV'), ('que', 'KS'), ('vou', 'VAUX'), ('receber', 'V'), ('com', 'PREP'), ('muito', 'PROADJ'), ('orgulho', 'N'), (',', ','), ('na', 'KS'), ('próxima', 'ADJ'), ('terça-feira', 'N'), (',', ','), ('o', 'ART'), ('título', 'N'), ('de', 'PREP'), ('cidadão', 'N'), ('Amazonense', 'NPROP'), (',', ','), ('grande', 'ADJ'), ('honra', 'N'), ('concebido', 'PCP'), ('pela', 'NPROP'), ('deputada', 'N'), ('@', 'N'), ('alecampelo', 'N'), ('.', '.')], [('Muito', 'ADV'), ('obrigado', 'PCP'), ('a', 'PREP|+'), ('todos', 'PROADJ'), ('os', 'ART'), ('envolvidos', 'N'), ('por', 'PREP'), ('esse', 'PROADJ'), ('grande', 'ADJ'), ('momento', 'N'), ('da', 'N'), ('minha', 'PROADJ'), ('vida', 'N'), ('.', '.')], [('Estamos', 'V'), ('trabalhando', 'V'), ('duro', 'ADJ'), ('para', 'PREP'), ('que', 'KS'), ('a', 'ART'), ('gastronomia', 'N'), ('amazonense', 'N'), ('seja', 'VAUX'), ('representada', 'PCP'), ('com', 'PREP'), ('muito', 'PROADJ'), ('carinho', 'N'), ('e', 'KC'), ('muita', 'PROADJ'), ('verdade', 'N'), ('mundo', 'N'), ('a', 'PREP|+'), ('fora', 'PREP|+'), ('.', '.')], [('🇧🇷🇧🇷🇧🇷', 'N')]]
#
#
# Comment:
# [[('👏👏👏', 'N')]]
#
#
# Comment:
# [[('Parabéns', 'N'), (',', ','), ('você', 'PROPESS'), ('virou', 'V'), ('a', 'ART'), ('cara', 'N'), ('de', 'PREP'), ('Manaus', 'NPROP')]]
#
#
# Comment:
# [[('Merecidíssimo', 'N'), ('👏👏👏', 'N')]]
#
#
# Comment:
# [[('👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼', 'N')]]
#
#
# Comment:
# [[('Finalmente', 'ADV'), (',', ','), ('mais', 'ADV'), ('que', 'KS'), ('merecido', 'PCP'), ('!', '!'), ('!', '!'), ('!', '!')], [('👏👏👏👏👏', 'N')]]
#
#
# Comment:
# [[('Merecido', 'N'), ('!', '!')], [('Parabéns', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('Parabéns', 'N'), ('!', '!')], [('Merecidíssimo', 'N'), ('!', '!'), ('!', '!')], [('!', '!'), ('👏🏻👏🏻👏🏻🎉🎉🎉', 'N')]]
#
#
# Comment:
# [[('Parabéns', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('👏', 'N')]]
#
#
# Caption:
# [[('#', 'N'), ('Repost', 'N'), ('@', 'N'), ('felipeschaedler_', 'N'), ('・・・', 'N'), ('5', 'N|AP'), ('de', 'PREP'), ('setembro', 'N'), (',', ','), ('dia', 'N'), ('da', 'N'), ('Amazônia', 'NPROP'), ('.', 'NPROP')], [('Por', 'PREP'), ('menos', 'PREP'), ('fumaça', 'N'), (',', ','), ('mais', 'ADV'), ('respeito', 'N'), ('pelos', 'N'), ('povos', 'N'), ('da', 'N'), ('floresta', 'ADJ'), (',', ','), ('pela', 'NPROP'), ('biodiversidade', 'N'), ('...', 'N'), ('Vida', 'N'), ('longa', 'ADJ'), ('a', 'PREP|+'), ('uma', 'ART'), ('das', 'NPROP'), ('regiões', 'N'), ('mais', 'ADV'), ('importantes', 'ADJ'), ('do', 'KS'), ('planeta', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('👏🌷❤️🙏', 'N')]]
#
#
# Caption:
# [[('Experimente', 'V|+'), ('nossos', 'PROADJ'), ('drinks', 'N|EST'), ('exclusivos', 'ADJ'), ('com', 'PREP'), ('o', 'ART'), ('genuíno', 'ADJ'), ('sabor', 'N'), ('da', 'N'), ('Amazônia', 'NPROP'), ('.', 'NPROP')]]
#
#
# Comment:
# [[('Amo', 'V'), ('os', 'ART'), ('dois', 'NUM')]]
#
#
# Comment:
# [[('Vocês', 'PROPESS'), ('fazem', 'V'), ('reserva', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('Especiais', 'NPROP'), ('...', 'NPROP'), ('.', 'NPROP')]]
#
#
# Comment:
# [[('😍', 'N')]]
#
#
# Comment:
# [[('😍😍😍', 'N')]]
#
#
# Caption:
# [[('Aguardamos', 'V'), ('vocês', 'PROPESS'), ('nesta', 'N'), ('segunda-feira', 'N'), ('!', '!')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('❤️', 'N')]]
#
#
# Comment:
# [[('😓😓😓', 'N')]]
#
#
# Caption:
# [[('Das', 'NPROP'), ('combinações', 'N'), ('que', 'PRO-KS-REL'), ('mais', 'ADV'), ('gostamos', 'V'), ('mais', 'ADV'), ('gosta', 'V'), ('no', 'PREP|+'), ('Amazonas', 'NPROP'), (',', ','), ('uma', 'ART'), ('delas', 'N'), ('é', 'V'), ('composta', 'PCP'), ('por', 'PREP|+'), ('três', 'NUM'), ('principais', 'ADJ'), ('protagonistas', 'N'), (':', ':'), ('Pirarucu', 'N'), (',', ','), ('Queijo', 'NPROP'), ('Coalho', 'N'), ('e', 'KC'), ('Banana', 'N'), ('da', 'N'), ('Terra', 'NPROP'), ('.', 'NPROP')], [('Experimente', 'V|+'), ('o', 'PROPESS'), ('nosso', 'PROADJ'), ('Pirarucu', 'N'), ('Amazônico', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('Combinação', 'N'), ('perfeita', 'ADJ'), ('😋😍', 'N')]]
#
#
# Comment:
# [[('Ai', 'IN'), ('que', 'KS'), ('delicia', 'N'), ('😋🙄', 'N')]]
#
#
# Comment:
# [[('Desde', 'PREP'), ('Manaus', 'NPROP'), (':', ':'), ('Está', 'V'), ("'paidégua", 'N'), ("'", "'"), ('ou', 'KC'), ('será', 'V'), (',', ','), ('está', 'V'), ("'xibata", 'N'), ("'", "'"), ('!', '!')]]
#
#
# Comment:
# [[('Adoro', 'V'), ('!', '!'), ('!', '!'), ('!', '!')], [('Só', 'PDEN'), ('que', 'KS'), ('pra', 'PREP'), ('mim', 'PROPESS'), (',', ','), ('é', 'V'), ('banana', 'N'), ('pacovã.🤣🤣🤣', 'N')]]
#
#
# Comment:
# [[('E', 'KC'), ('que', 'KS'), ('combinação', 'N'), ('!', '!')], [('👏👏👏❤️❤️❤️', 'N')]]
#
#
# Comment:
# [[('👏👏👏👏👏', 'N')]]
#
#
# Comment:
# [[('Seguraaaaa', 'N'), ('@', 'N'), ('plantas_e_plantas_byjr', 'N'), ('.', '.')], [('Vão', 'VAUX'), ('!', '!')]]
#
#
# Comment:
# [[('Ai', 'IN'), ('meu', 'PROADJ'), ('coração', 'N'), ('♥😭', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('marita.moura', 'N'), ('Muitoooooo', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('😍', 'N')]]
#
#
# Comment:
# [[('Hummmmmm', 'N'), ('...', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('@', 'N'), ('mari.solla', 'N'), ('restaurante', 'N'), ('que', 'PRO-KS-REL'), ('falei', 'V'), (',', ','), ('em', 'PREP|+'), ('Manaus', 'NPROP'), ('...', 'NPROP')]]
#
#
# Comment:
# [[('Onde', 'ADV'), ('em', 'PREP|+'), ('São', 'NPROP'), ('Paulo', 'NPROP'), ('?', '?')], [('Preciso', 'V'), ('matar', 'V'), ('a', 'ART'), ('saudade', 'N'), ('desse', 'V'), ('prato', 'N'), ('maravilhoso', 'ADJ'), ('!', '!')], [('!', '!')]]
#
#
# Comment:
# [[('Oi', 'IN'), (',', ','), ('@', 'N'), ('marlassantosy', 'N'), ('!', '!')], [('O', 'ART'), ('@', 'N'), ('banzeirosp', 'N'), ('fica', 'V'), ('na', 'PREP|+'), ('Tabapuã', 'NPROP'), (',', ','), ('830', 'N'), (',', ','), ('Itaim', 'NPROP'), ('.', 'NPROP')], [('Mas', 'KC'), ('esse', 'PROADJ'), ('prato', 'N'), ('é', 'V'), ('do', 'KS'), ('cardápio', 'N'), ('de', 'PREP'), ('Manaus', 'NPROP'), (',', ','), ('viu', 'V'), ('?', '?')], [('Não', 'ADV'), ('deixe', 'VAUX'), ('de', 'PREP'), ('conferir', 'V'), ('as', 'ART'), ('novidades', 'N'), ('do', 'KS'), ('nosso', 'PROADJ'), ('cardápio', 'N'), ('paulistano', 'ADJ'), ('no', 'PREP|+'), ('Instagram', 'N'), ('de', 'PREP'), ('lá', 'ADV'), ('.', '.')], [(':', ':'), (')', ')')]]
#
#
# Caption:
# [[('Hoje', 'ADV'), ('é', 'V'), ('um', 'ART'), ('dia', 'N'), ('importante', 'ADJ'), ('para', 'PREP'), ('a', 'ART'), ('família', 'N'), ('Banzeiro', 'N'), ('.', '.')], [('Abrimos', 'N'), ('oficialmente', 'ADV'), ('as', 'ART'), ('portas', 'N'), ('da', 'N'), ('nossa', 'PROADJ'), ('casa', 'N'), ('em', 'PREP|+'), ('São', 'NPROP'), ('Paulo', 'NPROP'), ('!', '!')], [('Bem-vindos', 'N'), ('ao', 'PREP'), ('@', 'N'), ('BanzeiroSP', 'N'), ('.', '.')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('@', 'N'), ('chrisoliveirasaraiva', 'N'), ('se', 'PROPESS'), ('Deus', 'NPROP'), ('permitir', 'V'), ('nós', 'PROPESS'), ('vamos', 'VAUX'), ('nesse', 'N'), ('restaurante', 'N'), ('.', '.')], [('😍😍😍😍', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('likafeil', 'N'), ('Capaz', 'ADJ'), ('!', '!'), ('!', '!'), ('!', '!')], [('Bahhh..', 'N'), ('mais', 'ADV'), ('perto', 'PREP|+'), ('que', 'PRO-KS'), ('nunca', 'ADV'), ('...', '...')]]
#
#
# Comment:
# [[('@', 'N'), ('joaopedro_rsrocha', 'N'), ('só', 'PDEN'), ('vai', 'VAUX'), ('economizar', 'V'), ('9h', 'N|HOR'), ('de', 'PREP'), ('voo', 'N'), ('🙏🏼🙏🏼', 'N')]]
#
#
# Comment:
# [[('Nesse', 'N'), ('tu', 'PROPESS'), ('tinha', 'V'), ('que', 'KS'), ('estagiar', 'N'), ('@', 'N'), ('luanaprettodecastro', 'N'), ('💕💕', 'N')]]
#
#
# Comment:
# [[('muito', 'ADV'), ('sucesso', 'N'), ('ao', 'PREP'), ('Banzeiro', 'N'), ('aonde', 'ADV-KS-REL'), ('fiz', 'V'), ('parte', 'N'), ('dessa', 'N'), ('família', 'ADJ'), ('e', 'KC'), ('aprendi', 'V'), ('muito', 'ADV'), ('sobre', 'PREP'), ('comida', 'N'), ('e', 'KC'), ('valores', 'N'), ('pessoas', 'N'), ('amizades', 'N'), ('que', 'PRO-KS-REL'), ('vou', 'VAUX'), ('levar', 'V'), ('pra', 'PREP'), ('sempre', 'ADV'), ('na', 'PREP|+'), ('minha', 'PROADJ'), ('vida', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('Sucesso', 'NPROP'), ('a', 'PREP|+'), ('todos', 'PROADJ'), ('!', '!'), ('!', '!'), ('!', '!'), ('!', '!')], [('Feliz', 'NPROP'), ('em', 'PREP|+'), ('ter', 'V'), ('um', 'ART'), ('Banzeiro', 'N'), ('aqui', 'ADV'), ('em', 'PREP|+'), ('Sampa', 'N'), ('👏🏻👏🏻👏🏻', 'N')]]
#
#
# Comment:
# [[('Com', 'PREP'), ('td', 'N'), ('talento', 'N'), ('banzeiro', 'N'), (',', ','), ('esse', 'PROADJ'), ('décor', 'N|EST'), (',', ','), ('não', 'ADV'), ('tem', 'V'), ('errada', 'PCP'), ('...', '...')]]
#
#
# Comment:
# [[('@', 'N'), ('erickmotta', 'N'), ('que', 'PRO-KS-REL'), ('dia', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('angerson_', 'N'), ('que', 'PRO-KS-REL'), ('tal', 'PROADJ'), ('domingo', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('@', 'N'), ('erickmotta', 'N'), ('aprovo', 'N'), ('domingo', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('silvialmeidas', 'N'), (',', ','), ('vamos', 'VAUX'), ('almoçar', 'V'), ('então', 'ADV'), ('?', '?')], [('Vou', 'VAUX'), ('trabalhar', 'V'), ('à', 'ADV'), ('noite', 'ADV'), ('.', '.')], [('@', 'N'), ('angerson_', 'N'), (',', ','), ('fechado', 'PCP'), ('?', '?')]]
#
#
# Comment:
# [[('@', 'N'), ('silvialmeidas', 'N'), ('@', 'N'), ('erickmotta', 'N'), ('domingo', 'N')]]
#
#
# Comment:
# [[('👏👏👏👌👌👌🔝🔝🔝', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('paulagertrudes', 'N'), ('@', 'N'), ('helenadecastro', 'N'), ('super', 'ADJ'), ('recomendo', 'V'), ('!', '!')]]
#
#
# Comment:
# [[('@', 'N'), ('roose_diane', 'N')]]
#
#
# Comment:
# [[('Ficou', 'V'), ('lindo', 'ADJ'), ('e', 'KC'), ('charmoso', 'ADJ'), ('!', '!'), ('!', '!')], [('!', '!'), ('👏🏽👏🏽👏🏽', 'N'), ('@', 'N'), ('angelamcelestino', 'N')]]
#
#
# Comment:
# [[('❤️❤️❤️', 'N'), ('muito', 'ADV'), ('sucesso', 'N'), (',', ','), ('aqui', 'ADV'), ('e', 'KC'), ('lá', 'ADV'), (',', ','), ('restaurante', 'N'), ('muito', 'ADV'), ('além', 'PREP|+'), ('da', 'NPROP'), ('comida', 'N'), (',', ','), ('com', 'PREP'), ('tradição', 'N'), ('e', 'KC'), ('valores', 'N'), ('.', '.')], [('👏👏', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('dmribeirof', 'N'), ('👏🏽👏🏽', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('juliapi', 'N'), ('conhece', 'V'), ('?', '?')]]
#
#
# Comment:
# [[('@', 'N'), ('baagentile', 'N'), ('clarooo', 'N'), ('!', '!'), ('!', '!')], [('É', 'V'), ('muito', 'ADV'), ('mara', 'N'), ('em', 'PREP|+'), ('Manaus', 'NPROP'), (',', ','), ('vamos', 'VAUX'), ('combinar', 'V'), ('de', 'PREP'), ('ir', 'V'), ('esses', 'PROADJ'), ('dias', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('@', 'N'), ('sandrocolomba', 'N'), ('@', 'N'), ('fercolomba', 'N'), ('um', 'ART'), ('pouquinho', 'N'), ('do', 'KS'), ('Norte', 'NPROP'), ('aí', 'ADV'), ('pra', 'PREP'), ('vcs', 'N'), ('❤️', 'N')]]
#
#
# Comment:
# [[('Maravilha..sucesso', 'N'), ('!', '!')], [('!', '!')]]
#
#
# Caption:
# [[('Lentinula', 'N'), ('Raphanica', 'N'), ('pertence', 'V'), ('ao', 'PREP'), ('mesmo', 'PROADJ'), ('gênero', 'N'), ('do', 'KS'), ('cogumelo', 'N'), ('shitake', 'N'), (',', ','), ('um', 'ART'), ('dos', 'NPROP'), ('mais', 'ADV'), ('conhecidos', 'PCP'), ('e', 'KC'), ('consumidos', 'PCP'), ('no', 'PREP|+'), ('mundo', 'N'), ('.', '.')], [('Ele', 'PROPESS'), ('se', 'PROPESS'), ('diferencia', 'V'), ('dos', 'NPROP'), ('outros', 'NPROP'), ('cogumelos', 'N'), ('pelo', 'PDEN'), ('sabor', 'N'), (',', ','), ('textura', 'N'), ('e', 'KC'), ('porque', 'KS'), ('não', 'ADV'), ('é', 'V'), ('cultivado', 'PCP'), ('em', 'PREP|+'), ('outros', 'PROADJ'), ('lugares', 'N'), ('do', 'KS'), ('mundo', 'N'), ('.', '.')], [('Além', 'PREP|+'), ('disso', 'ADV'), (',', ','), ('o', 'ART'), ('Brasil', 'NPROP'), ('é', 'V'), ('um', 'ART'), ('País', 'N'), ('que', 'PRO-KS-REL'), ('está', 'V'), ('começando', 'V'), ('a', 'ART'), ('comer', 'V'), ('cogumelo', 'N'), ('e', 'KC'), (',', ','), ('com', 'PREP'), ('o', 'ART'), ('consumo', 'N'), ('crescente', 'ADJ'), (',', ','), ('será', 'V'), ('um', 'ART'), ('diferencial', 'N'), ('ter', 'VAUX'), ('um', 'ART'), ('produto', 'N'), ('com', 'PREP'), ('a', 'ART'), ('marca', 'N'), ('da', 'N'), ('Amazônia', 'NPROP'), ('.', 'NPROP')], [('Do', 'NPROP'), ('ponto', 'N'), ('de', 'PREP'), ('vista', 'N'), ('gastronômico', 'N'), (',', ','), ('o', 'ART'), ('Raphanica', 'N'), ('precisa', 'V'), ('ser', 'V'), ('desidratado', 'N'), ('e', 'KC'), ('reidratado', 'N'), ('com', 'PREP'), ('água', 'N'), ('gelada', 'PCP'), ('para', 'PREP'), ('atingir', 'V'), ('um', 'ART'), ('pico', 'N'), ('de', 'PREP'), ('sabor', 'N'), ('.', '.')], [('No', 'KC'), ('Banzeiro', 'N'), (',', ','), ('ele', 'PROPESS'), ('é', 'V'), ('a', 'ART'), ('estrela', 'N'), ('do', 'KS'), ('prato', 'N'), ('.', '.')], [('Você', 'PROPESS'), ('já', 'ADV'), ('provou', 'V'), ('o', 'ART'), ('nosso', 'PROADJ'), ('Risoto', 'NPROP'), ('de', 'NPROP'), ('Cogumelo', 'N'), ('Amazônico', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('Nossa', 'PROADJ'), ('!', '!')], [('Quero', 'V'), ('!', '!')]]
#
#
# Comment:
# [[('Quero', 'V'), ('!', '!')]]
#
#
# Comment:
# [[('Quero', 'V'), ('com', 'PREP'), ('cogumelo', 'N'), ('yanomami', 'N'), ('e', 'KC'), ('com', 'PREP'), ('@', 'N'), ('origensbrasil', 'N'), ('👍🏻👊🏻', 'N')]]
#
#
# Caption:
# [[('Pirarucu', 'N'), ('empanado', 'N'), ('na', 'ADV'), ('Farinha', 'NPROP'), ('do', 'NPROP'), ('Uarini', 'N'), ('com', 'PREP'), ('Vinagrete', 'N'), (',', ','), ('um', 'ART'), ('dos', 'NPROP'), ('mais', 'ADV'), ('tradicionais', 'ADJ'), ('da', 'NPROP'), ('casa', 'N'), ('.', '.')], [('Vamos', 'VAUX'), ('almoçar', 'V'), ('?', '?')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('@', 'N'), ('edumagnoni', 'N'), ('Nosso', 'PROADJ'), ('cardápio', 'N'), ('de', 'PREP'), ('SP', 'NPROP'), ('está', 'VAUX'), ('cheio', 'ADJ'), ('de', 'PREP|+'), ('novidades', 'N'), (',', ','), ('Edu', 'NPROP'), ('!', '!')], [('Falta', 'V'), ('pouco', 'ADV'), ('!', '!')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('@', 'N'), ('izabel__souzza', 'N'), ('Vem', 'V'), ('jantar', 'N'), ('com', 'PREP'), ('a', 'ART'), ('gente', 'N'), (',', ','), ('Izabel', 'NPROP'), ('!', '!')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('@', 'N'), ('restaurantebanzeiro', 'N'), ('falta', 'V'), ('pouco..', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('gustavomedeiroos_', 'N'), ('deu', 'V'), ('água', 'N'), ('na', 'ADV'), ('boca', 'N')]]
#
#
# Caption:
# [[('Você', 'PROPESS'), ('já', 'ADV'), ('pode', 'VAUX'), ('fazer', 'V'), ('sua', 'PROADJ'), ('reserva', 'N'), (',', ','), ('para', 'PREP'), ('a', 'ART'), ('partir', 'PREP|+'), ('do', 'KS'), ('dia', 'N'), ('26', 'N|AP'), (',', ','), ('através', 'PREP|+'), ('do', 'KS'), ('link', 'N'), ('na', 'ADV'), ('descrição', 'N'), ('do', 'KS'), ('perfil', 'N'), ('do', 'KS'), ('@', 'N'), ('BanzeiroSP', 'N'), ('!', '!')], [('Estamos', 'V'), ('ansiosos', 'N'), ('para', 'PREP'), ('recebê-los', 'N'), ('!', '!')], [('💚', 'N'), ('#', 'N'), ('Repost', 'N'), ('@', 'N'), ('banzeirosp', 'N'), ('・・・', 'N'), ('Para', 'PREP'), ('curtir', 'V'), ('um', 'ART'), ('momento', 'N'), ('relax', 'N'), ('após', 'PREP'), ('o', 'ART'), ('almoço', 'N'), ('.', '.')], [('Projeto', 'N'), ('@', 'N'), ('claudianerlingarquitetura', 'N'), (',', ','), ('nossa', 'PROADJ'), ('artista', 'N'), ('desde', 'PREP'), ('sempre', 'ADV'), ('!', '!')]]
#
#
# Comment:
# [[('@', 'N'), ('juliana_andreotti', 'N'), ('ameii', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('juliana_andreotti', 'N'), ('ameii', 'N')]]
#
#
# Comment:
# [[('😱😱😱', 'N'), ('Não', 'ADV'), ('acredito', 'V'), ('...', '...'), ('preciso', 'ADJ'), ('conhecer', 'V'), ('!', '!'), ('!', '!'), ('!', '!')], [('@', 'N'), ('klebermh', 'N'), ('precisamos', 'V'), ('ir', 'V'), ('para', 'PREP'), ('vc', 'N'), ('apreciar', 'V'), ('um', 'ART'), ('maravilhoso', 'ADJ'), ('tambaqui', 'N'), ('!', '!')], [('🤗🤗🤗', 'N')]]
#
#
# Caption:
# [[('Aquela', 'PROADJ'), ('Matrinxã', 'N'), ('torradinha', 'N'), ('por', 'PREP'), ('fora', 'ADV'), ('e', 'KC'), ('suculenta', 'N'), ('por', 'PREP'), ('dentro', 'PREP|+'), (',', ','), ('do', 'KS'), ('jeito', 'N'), ('que', 'PRO-KS-REL'), ('a', 'ART'), ('gente', 'N'), ('gosta', 'V'), ('.', '.')], [('Vamos', 'VAUX'), ('jantar', 'V'), ('no', 'PREP|+'), ('Banzeiro', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('@', 'N'), ('windsorferreira', 'N'), ('top', 'ADJ|EST'), ('hein', 'IN'), ('irmão', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('eurodrigodlima', 'N'), ('vamos', 'VAUX'), ('?', '?')]]
#
#
# Caption:
# [[('Hoje', 'ADV'), ('abriremos', 'V'), ('para', 'PREP'), ('o', 'ART'), ('público', 'N'), ('apenas', 'PDEN'), ('no', 'KC'), ('horário', 'N'), ('do', 'KS'), ('almoço', 'N'), ('.', '.')], [('Amanhã', 'ADV'), (',', ','), ('sexta-feira', 'N'), (',', ','), ('retornamos', 'V'), ('com', 'PREP'), ('as', 'ART'), ('atividades', 'N'), ('normais', 'ADJ'), ('.', '.')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('Pedi', 'V'), ('uma', 'ART'), ('caipirinha', 'N'), ('banzeiro', 'N'), ('hoje', 'ADV'), ('e', 'KC'), ('veio', 'V'), ('MUITO', 'N'), ('ruim', 'ADJ'), ('.', '.')], [('Impossível', 'ADJ'), ('de', 'PREP|+'), ('beber', 'V'), ('.', '.')], [('Inclusive', 'PDEN'), ('todos', 'PROADJ'), ('da', 'NPROP'), ('mesa', 'N'), ('experimentaram', 'N'), ('e', 'KC'), ('chegaram', 'V'), ('a', 'ART'), ('mesma', 'PROADJ'), ('conclusão', 'N'), ('.', '.')], [('O', 'ART'), ('atendimento', 'N'), ('hoje', 'ADV'), ('não', 'ADV'), ('foi', 'VAUX'), ('nada', 'PROSUB'), ('cordial', 'ADJ'), ('também', 'PDEN'), ('.', '.')], [('Lamentável', 'N'), ('.', '.')], [('Informei', 'N'), ('a', 'PREP|+'), ('uma', 'ART'), ('moça', 'N'), ('sobre', 'PREP'), ('minha', 'PROADJ'), ('insatisfação', 'N'), ('e', 'KC'), ('nada', 'PROSUB'), ('fez', 'V'), ('em', 'PREP|+'), ('relação', 'PREP|+'), ('a', 'ART'), ('isso', 'PROSUB'), ('.', '.')], [('Pensarei', 'N'), ('duas', 'NUM'), ('vezes', 'N'), ('antes', 'ADV'), ('de', 'PREP|+'), ('convidar', 'V'), ('minha', 'PROADJ'), ('família', 'N'), ('de', 'PREP'), ('novo', 'ADJ'), ('pra', 'PREP'), ('ir', 'V'), ('a', 'ART'), ('esse', 'PROADJ'), ('restaurante', 'N'), ('.', '.')]]
#
#
# Caption:
# [[('Direto', 'NPROP'), ('da', 'NPROP'), ('nossa', 'PROADJ'), ('cozinha', 'N'), (',', ','), ('tá', 'VAUX'), ('saindo', 'V'), ('a', 'ART'), ('primeira', 'ADJ'), ('Matrinxã', 'N'), ('Recheada', 'N'), ('desta', 'PROADJ'), ('terça-feira', 'N'), ('!', '!')], [('Vamos', 'VAUX'), ('almoçar', 'V'), ('?', '?')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('Top', 'NPROP')]]
#
#
# Comment:
# [[('Noooossaa', 'N'), ('🤤', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('adrianacookjp', 'N'), (',', ','), ('wuau', 'N'), ('\U0001f9d0😲😋😋\U0001f970', 'N'), ('!', '!')], [('Que', 'PROADJ'), ('luxo', 'N'), ('!', '!'), ('!', '!')], [('!', '!')]]
#
#
# Comment:
# [[('Esperando', 'NPROP'), ('ela', 'PROPESS'), ('chegar', 'V'), ('aqui', 'ADV'), ('em', 'PREP|+'), ('Sampa', 'N'), ('😍', 'N')]]
#
#
# Caption:
# [[('Estamos', 'V'), ('passando', 'V'), ('apenas', 'PDEN'), ('para', 'PREP'), ('deixar', 'V'), ('essa', 'PROADJ'), ('ideia', 'N'), ('para', 'PREP'), ('o', 'ART'), ('seu', 'PROADJ'), ('sábado', 'N'), ('!', '!')], [('As', 'ART'), ('Costelinhas', 'N'), ('de', 'PREP'), ('Tambaqui', 'N'), ('são', 'V'), ('preparadas', 'PCP'), ('de', 'PREP'), ('diversas', 'PROADJ'), ('formas', 'N'), ('aqui', 'ADV'), ('no', 'PREP|+'), ('Banzeiro', 'N'), (',', ','), ('qual', 'PROSUB'), ('é', 'V'), ('a', 'ART'), ('sua', 'PROADJ'), ('preferida', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('São', 'V'), ('muuuito', 'N'), ('boas.😍😋', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('kakauuu', 'N'), (',', ','), ('olha', 'V'), ('o', 'ART'), ('que', 'PRO-KS-REL'), ('vai', 'VAUX'), ('abrir', 'V'), ('aqui', 'ADV')]]
#
#
# Comment:
# [[('@', 'N'), ('augustobatista91', 'N'), ('mt', 'N'), ('bom', 'ADJ'), ('!', '!')]]
#
#
# Caption:
# [[('Inconfundíveis', 'N'), ('.', '.')], [('Essa', 'PROADJ'), ('é', 'V'), ('a', 'ART'), ('palavra', 'N'), ('que', 'PRO-KS-REL'), ('usamos', 'V'), ('para', 'PREP'), ('descrever', 'V'), ('os', 'ART'), ('nossos', 'PROADJ'), ('Dadinhos', 'N'), ('de', 'PREP'), ('Tapioca', 'N'), ('com', 'PREP'), ('Geleia', 'N'), ('de', 'PREP'), ('Cupuaçu', 'N'), (',', ','), ('uma', 'ART'), ('Entrada', 'N'), ('essencial', 'ADJ'), ('para', 'PREP'), ('quem', 'PRO-KS'), ('deseja', 'V'), ('experimentar', 'V'), ('um', 'ART'), ('dos', 'NPROP'), ('sabores', 'N'), ('mais', 'ADV'), ('característicos', 'ADJ'), ('da', 'NPROP'), ('Amazônia', 'NPROP'), ('.', 'NPROP')]]
#
#
# Comment:
# [[('Amo', 'V'), ('simetria', 'N'), ('gastronômica❤️', 'N')]]
#
#
# Comment:
# [[('Hummm', 'N'), ('😋😋😋Qdo', 'N'), ('o', 'ART'), ('Banzeiro', 'N'), ('vai', 'VAUX'), ('abrir', 'V'), ('no', 'PREP|+'), ('Itaim', 'NPROP'), ('aqui', 'ADV'), ('em', 'PREP|+'), ('SP', 'NPROP'), ('?', '?')]]
#
#
# Comment:
# [[('@', 'N'), ('restaurantebanzeiro', 'N'), ('qualquer', 'PROADJ'), ('dia', 'N'), ('apareço', 'N'), ('por', 'PREP'), ('aí', 'ADV'), ('novamente', 'ADV'), ('amo', 'V'), ('tudo', 'PROSUB'), ('que', 'PRO-KS-REL'), ('vcs', 'N'), ('fazem', 'V'), ('♥️', 'N')]]
#
#
# Caption:
# [[('O', 'ART'), ('nosso', 'PROADJ'), ('‘', 'N'), ('bom', 'ADJ'), ('dia', 'N'), ('’', 'N'), ('de', 'PREP'), ('hoje', 'ADV'), ('é', 'V'), ('com', 'PREP'), ('uma', 'ART'), ('palhinha', 'N'), ('do', 'KS'), ('que', 'KS'), ('vem', 'V'), ('por', 'PREP'), ('aí', 'ADV'), ('.', '.')], [('Mais', 'ADV'), ('especificamente', 'ADV'), ('na', 'PREP|+'), ('Rua', 'NPROP'), ('Tabapuã', 'NPROP'), (',', ','), ('830', 'N'), ('.', '.')], [('Por', 'PREP'), ('falar', 'V'), ('nisso', 'N'), (',', ','), ('você', 'PROPESS'), ('já', 'ADV'), ('segue', 'V'), ('o', 'ART'), ('@', 'N'), ('BanzeiroSP', 'N'), ('?', '?')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('@', 'N'), ('dmribeirof', 'N'), ('eu', 'PROPESS'), ('estou', 'VAUX'), ('dentro', 'PREP|+'), ('!', '!')], [('😊', 'N')]]
#
#
# Comment:
# [[('Parece', 'V'), ('que', 'KS'), ('depois', 'PREP'), ('de', 'PREP'), ('abrirem', 'N'), ('em', 'PREP|+'), ('São', 'NPROP'), ('Paulo', 'NPROP'), (',', ','), ('a', 'ART'), ('próxima', 'ADJ'), ('abertura', 'N'), ('será', 'VAUX'), ('em', 'PREP'), ('Brasília', 'NPROP'), ('...', 'NPROP'), ('..', 'N'), ('Aleluia', 'NPROP'), ('...', 'NPROP'), ('.', 'NPROP')]]
#
#
# Comment:
# [[('@', 'N'), ('dmribeirof', 'N'), ('vamos', 'VAUX'), ('ou', 'KC'), ('bora', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('@', 'N'), ('restaurantebanzeiro', 'N'), ('vocês', 'PROPESS'), ('já', 'ADV'), ('estão', 'V'), ('fazendo', 'V'), ('reservas', 'N'), ('para', 'PREP'), ('a', 'ART'), ('última', 'ADJ'), ('semana', 'N'), ('de', 'PREP'), ('agosto', 'N'), (',', ','), ('para', 'PREP'), ('o', 'ART'), ('@', 'N'), ('banzeirosp', 'N'), ('?', '?')]]
#
#
# Caption:
# [[('Sexta-feira', 'N'), ('combina', 'V'), ('com', 'PREP'), ('os', 'ART'), ('nossos', 'PROADJ'), ('Risotos', 'N'), ('.', '.')], [('Que', 'PROADJ'), ('horas', 'N'), ('você', 'PROPESS'), ('chega', 'V'), ('?', '?')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('Lindo', 'ADJ'), ('está', 'V'), ('...', '...'), ('😍', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('nilvedalmolin', 'N'), ('Obrigado', 'PCP'), (',', ','), ('Nilve', 'N'), ('!', '!')], [('🙏🏼🙂', 'N')]]
#
#
# Caption:
# [[('As', 'ART'), ('Costelas', 'N'), ('de', 'PREP'), ('Tambaqui', 'N'), ('que', 'PRO-KS-REL'), ('nossos', 'PROADJ'), ('clientes', 'N'), ('e', 'KC'), ('amigos', 'N'), ('tanto', 'KC|['), ('gostam', 'V'), ('são', 'V'), ('servidas', 'PCP'), ('de', 'PREP'), ('diversas', 'PROADJ'), ('formas', 'N'), ('aqui', 'ADV'), ('no', 'PREP|+'), ('Banzeiro', 'N'), ('.', '.')], [('Quais', 'PROSUB'), ('você', 'PROPESS'), ('já', 'ADV'), ('provou', 'V'), ('?', '?')]]
#
#
# Comment:
# [[('Quando', 'KS'), ('chegam', 'V'), ('em', 'PREP|+'), ('SP', 'NPROP'), ('?', '?')], [('Amo', 'V'), ('!', '!')]]
#
#
# Comment:
# [[('@', 'N'), ('daniellesiriani', 'N'), ('Já', 'ADV'), ('em', 'PREP|+'), ('agosto', 'N'), ('!', '!')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('@', 'N'), ('luci8439', 'N'), ('Tá', 'V'), ('chegando', 'V'), ('a', 'ART'), ('hora', 'N'), (',', ','), ('Luci', 'N'), ('!', '!')], [('Acompanhe', 'V'), ('o', 'ART'), ('Instagram', 'N'), ('@', 'N'), ('banzeirosp', 'N'), ('para', 'PREP'), ('mais', 'PREP'), ('informações', 'N'), ('.', '.')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('@', 'N'), ('restaurantebanzeiro', 'N'), ('obrigada', 'PCP'), ('...', '...')]]
#
#
# Caption:
# [[('Estão', 'V'), ('saindo', 'V'), ('os', 'ART'), ('primeiros', 'ADJ'), ('pedidos', 'N'), ('desta', 'PROADJ'), ('quinta-feira', 'N'), ('!', '!')], [('Vamos', 'VAUX'), ('almoçar', 'V'), ('?', '?')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('Queria', 'V'), ('tirar', 'V'), ('uma', 'ART'), ('dúvida', 'N')]]
#
#
# Comment:
# [[('Em', 'PREP|+'), ('outubro', 'N'), ('to', 'NPROP'), ('aí', 'ADV'), ('😍', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('rafaelacristina.93', 'N'), ('Já', 'ADV'), ('estamos', 'V'), ('te', 'PROPESS'), ('aguardando', 'V'), ('!', '!')], [(':', ':'), (')', ')')]]
#
#
# Caption:
# [[('O', 'ART'), ('nosso', 'PROADJ'), ('Tambaqui', 'N'), ('com', 'PREP'), ('Legumes', 'N'), ('é', 'V'), ('o', 'ART'), ('campeão', 'N'), ('de', 'PREP'), ('pedidos', 'N'), ('pra', 'PREP'), ('quem', 'PRO-KS'), ('quer', 'V'), ('aproveitar', 'V'), ('todo', 'PROADJ'), ('o', 'ART'), ('sabor', 'N'), ('de', 'PREP'), ('um', 'ART'), ('dos', 'NPROP'), ('nossos', 'PROADJ'), ('peixes', 'N'), ('mais', 'ADV'), ('conhecidos', 'PCP'), ('sem', 'PREP'), ('carboidratos', 'N'), ('nas', 'NPROP'), ('guarnições', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('😋😋😋😋😋😋', 'N')]]
#
#
# Comment:
# [[('😋😋', 'N')]]
#
#
# Comment:
# [[('😀😀😀😀😀😀', 'N')]]
#
#
# Comment:
# [[('👏👏👏👏👏👏👏👏', 'N'), ('Qualquer', 'PROADJ'), ('dia', 'N'), ('vou', 'V'), ('almoçar', 'V'), ('aí', 'ADV'), ('no', 'PREP|+'), ('Banzeiro', 'N'), ('.', '.')]]
#
#
# Caption:
# [[('Dica', 'N'), ('de', 'PREP'), ('sexta', 'N'), ('?', '?')], [('Costelas', 'N'), ('de', 'PREP'), ('Tambaqui', 'N'), ('ao', 'PREP'), ('molho', 'N'), ('Barbecue', 'N'), ('com', 'PREP'), ('Batatas', 'NPROP'), ('Rústicas', 'N'), ('.', '.')], [('Conheça', 'V'), ('o', 'ART'), ('melhor', 'ADJ'), ('restaurante', 'N'), ('de', 'PREP'), ('Manaus', 'NPROP'), (',', ','), ('segundo', 'PREP'), ('a', 'ART'), ('revista', 'N'), ('@', 'N'), ('vejacomerebeber', 'N'), ('!', '!')]]
#
#
# Comment:
# [[('Isso', 'PROSUB'), ('é', 'V'), ('sensacional', 'ADJ'), ('!', '!')], [('😋😋😋', 'N')]]
#
#
# Caption:
# [[('Pra', 'PREP'), ('começar', 'V'), ('a', 'ART'), ('semana', 'N'), (',', ','), ('um', 'ART'), ('dos', 'NPROP'), ('nossos', 'PROADJ'), ('pratos', 'N'), ('mais', 'ADV'), ('conhecidos', 'PCP'), (':', ':'), ('O', 'ART'), ('Pirarucu', 'N'), ('Amazônico', 'N'), ('!', '!')], [('Já', 'ADV'), ('estamos', 'V'), ('abertos', 'PCP'), ('e', 'KC'), ('prontos', 'ADJ'), ('para', 'PREP'), ('recebê-los', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('Mal', 'NPROP'), ('posso', 'VAUX'), ('esperar', 'V'), ('para', 'PREP'), ('ir', 'V'), ('até', 'PREP'), ('aí', 'ADV'), ('!', '!')]]
#
#
# Comment:
# [[('@', 'N'), ('jumbfranco', 'N'), ('😋😋😋', 'N')]]
#
#
# Comment:
# [[('Morriii', 'N'), ('😋', 'N')]]
#
#
# Caption:
# [[('Um', 'ART'), ('dos', 'NPROP'), ('pratos', 'N'), ('mais', 'ADV'), ('tradicionais', 'ADJ'), ('e', 'KC'), ('queridos', 'PCP'), ('da', 'NPROP'), ('Casa', 'NPROP'), ('é', 'V'), ('o', 'ART'), ('Filé', 'N'), ('de', 'PREP'), ('Pirarucu', 'N'), ('com', 'PREP'), ('Queijo', 'NPROP'), ('Coalho', 'N'), ('e', 'KC'), ('Banana', 'N'), ('da', 'N'), ('Terra', 'NPROP'), ('.', 'NPROP')], [('Já', 'ADV'), ('experimentou', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('Tudo', 'PROSUB'), ('que', 'PRO-KS-REL'), ('já', 'ADV'), ('experimentei', 'V'), ('é', 'V'), ('divino', 'N'), (',', ','), ('mas', 'KC'), ('esse', 'PROADJ'), ('ainda', 'ADV'), ('não', 'ADV'), ('provei', 'V'), ('.', '.')]]
#
#
# Comment:
# [[('👏👏', 'N')]]
#
#
# Comment:
# [[('Já', 'ADV'), ('e', 'KC'), ('vale', 'V'), ('a', 'ART'), ('pena', 'N'), ('comer', 'V'), ('de', 'PREP'), ('novo', 'ADJ'), ('!', '!'), ('👏👏', 'N')]]
#
#
# Comment:
# [[('Queria', 'V'), ('um', 'ART'), ('@', 'N'), ('restaurantebanzeiro', 'N'), ('em', 'PREP|+'), ('Fortaleza😍', 'N')]]
#
#
# Caption:
# [[('Ficamos', 'V'), ('felizes', 'ADJ'), ('pelo', 'PDEN'), ('reconhecimento', 'N'), (',', ','), ('pois', 'KC'), ('é', 'V'), ('primordial', 'ADJ'), ('poder', 'N'), ('contribuir', 'V'), ('com', 'PREP'), ('o', 'ART'), ('desenvolvimento', 'N'), ('sustentável', 'ADJ'), ('da', 'NPROP'), ('região', 'N'), ('.', '.')], [('As', 'ART'), ('comunidades', 'N'), ('ribeirinhas', 'N'), ('têm', 'V'), ('muito', 'ADV'), ('a', 'ART'), ('nos', 'PROPESS'), ('ensinar', 'V'), ('sobre', 'PREP'), ('a', 'ART'), ('nossa', 'PROADJ'), ('maior', 'ADJ'), ('riqueza', 'N'), (':', ':'), ('a', 'ART'), ('Amazônia', 'NPROP'), ('!', '!')]]
#
#
# Comment:
# [[('👏👏', 'N')]]
#
#
# Comment:
# [[('👏👏👏👏👏👏👏👏👏', 'N')]]
#
#
# Comment:
# [[('👏👏👏👏', 'N')]]
#
#
# Comment:
# [[('👏👏👏👏👏', 'N')]]
#
#
# Caption:
# [[('Costelas', 'N'), ('de', 'PREP'), ('Tambaqui', 'N'), ('assadas', 'N'), ('com', 'PREP'), ('Vinagrete', 'N'), ('para', 'PREP'), ('esta', 'PROADJ'), ('terça-feira', 'N'), ('.', '.')], [('Vamos', 'VAUX'), ('almoçar', 'V'), ('?', '?')]]
#
#
# Comment:
# [[('Chega', 'V'), ('logo', 'ADV'), ('em', 'PREP|+'), ('São', 'NPROP'), ('Paulo😋', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('daianedeabreu', 'N'), ('Estamos', 'V'), ('quase', 'ADV'), ('lá', 'ADV'), ('!', '!')], [('Agosto', 'N'), ('promete', 'V'), ('.', '.')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('@', 'N'), ('restaurantebanzeiro', 'N'), ('Estou', 'V'), ('aguardando', 'V'), ('ansiosa', 'ADJ'), ('!', '!')]]
#
#
# Caption:
# [[('Ajustando', 'N'), ('os', 'ART'), ('últimos', 'ADJ'), ('detalhes', 'N'), ('para', 'PREP'), ('servir', 'V'), ('os', 'ART'), ('primeiros', 'ADJ'), ('Pasteizinhos', 'N'), ('de', 'PREP'), ('Aviú', 'N'), ('desta', 'PROADJ'), ('terça-feira', 'N'), ('.', '.')], [('Quem', 'PRO-KS'), ('aí', 'ADV'), ('já', 'ADV'), ('provou', 'V'), ('?', '?')], [('🦐', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('felipesrodriguess', 'N'), ('por', 'PREP'), ('gentileza', 'N'), ('traga', 'V'), ('minha', 'PROADJ'), ('dúzia', 'N'), ('🤣😁', 'N')]]
#
#
# Comment:
# [[('Já', 'ADV'), ('comi', 'V'), ('Aviú', 'N'), (',', ','), ('mas', 'KC'), ('não', 'ADV'), ('o', 'ART'), ('pastel', 'N'), ('...', 'N'), ('😃', 'N')]]
#
#
# Comment:
# [[('👀👀', 'N'), ('o', 'ART'), ('que', 'PRO-KS-REL'), ('será', 'VAUX'), ('?', '?'), ('?', '?'), ('?', '?')], [('🤔🤔🤔🤔', 'N')]]
#
#
# Comment:
# [[('Chegam', 'V'), ('quando', 'KS'), ('a', 'ART'), ('Sampa', 'N'), ('?', '?')]]
#
#
# Caption:
# [[('Sexta', 'N'), ('é', 'V'), ('dia', 'N'), ('de', 'PREP'), ('alegria', 'N'), ('!', '!')], [('Nossa', 'PROADJ'), ('cozinha', 'N'), ('já', 'ADV'), ('está', 'V'), ('a', 'ART'), ('todo', 'PROSUB'), ('vapor', 'N'), (',', ','), ('pronta', 'ADJ'), ('para', 'PREP'), ('receber', 'V'), ('vocês', 'PROPESS'), ('da', 'NPROP'), ('melhor', 'ADJ'), ('forma', 'N'), ('possível', 'ADJ'), ('.', '.')], [('💛', 'N')]]
#
#
# Comment:
# [[('😍👏🏻👏🏻👏🏻As', 'N'), ('meninas', 'N'), ('mandando', 'V'), ('muito', 'ADV'), ('bem', 'ADV'), ('!', '!')]]
#
#
# Comment:
# [[('😋', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('d_nfonseca', 'N'), ('desejando', 'N')]]
#
#
# Comment:
# [[('Chef', 'N'), ('🔥', 'N'), ('Eva', 'NPROP')]]
#
#
# Caption:
# [[('Procurando', 'V'), ('um', 'ART'), ('jantar', 'N'), ('à', 'PREP|+'), ('luz', 'N'), ('de', 'PREP'), ('vela', 'N'), ('na', 'ADV'), ('noite', 'ADV'), ('mais', 'ADV'), ('romântica', 'ADJ'), ('do', 'KS'), ('ano', 'N'), (',', ','), ('com', 'PREP'), ('direito', 'N'), ('a', 'PREP|+'), ('taça', 'N'), ('de', 'PREP'), ('espumante', 'ADJ'), ('para', 'PREP'), ('brindar', 'V'), ('?', '?')], [('Então', 'ADV'), (',', ','), ('o', 'ART'), ('Banzeiro', 'N'), ('é', 'V'), ('seu', 'PROADJ'), ('destino', 'N'), ('certo', 'ADJ'), ('!', '!')], [('Garanta', 'N'), ('sua', 'PROADJ'), ('reserva', 'N'), (':', ':'), ('3234-1621/', 'N'), ('98437-0274/', 'N'), ('98400', 'N'), ('3200', 'N'), ('.', '.')], [('Amaremos', 'N'), ('receber', 'V'), ('vocês', 'PROPESS'), ('!', '!')], [('♥️', 'N')]]
#
#
# Comment:
# [[('valores', 'N'), ('e', 'KC'), ('cardapio', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('Valores', 'N'), ('e', 'KC'), ('cardápio', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('Qual', 'PROSUB'), ('o', 'ART'), ('cardápio', 'N'), ('é', 'V'), ('o', 'ART'), ('valor', 'N'), ('?', '?')]]
#
#
# Caption:
# [[('Sugestão', 'N'), ('de', 'PREP'), ('hoje', 'ADV'), ('?', '?')], [('Nosso', 'PROADJ'), ('famoso', 'ADJ'), ('Parmegiana', 'N'), ('de', 'PREP'), ('Pirarucu', 'N'), ('para', 'PREP'), ('esse', 'PROADJ'), ('domingão', 'N'), ('.', '.')], [('Vamos', 'VAUX'), ('almoçar', 'V'), ('?', '?')], [(':', ':'), (')', ')')]]
#
#
# Comment:
# [[('Quando', 'KS'), ('estará', 'V'), ('pronto', 'ADJ'), ('o', 'ART'), ('restaurante', 'N'), ('em', 'PREP|+'), ('SP', 'NPROP'), ('?', '?')]]
#
#
# Caption:
# [[('Sexta-feira', 'N'), ('é', 'V'), ('um', 'ART'), ('ótimo', 'ADJ'), ('dia', 'N'), ('para', 'PREP'), ('experimentar', 'V'), ('a', 'ART'), ('nossa', 'PROADJ'), ('Matrinxã', 'N'), ('ao', 'PREP'), ('Molho', 'N'), ('de', 'PREP'), ('Limões', 'N'), ('!', '!')], [('🍋', 'N')]]
#
#
# Comment:
# [[('Saudade', 'N'), ('deste', 'N'), ('restaurante', 'N'), ('.', '.')], [('Muito', 'ADV'), ('bom', 'ADJ'), ('!', '!'), ('!', '!')], [('!', '!')]]
#
#
# Comment:
# [[('@', 'N'), ('fcoreginaldo', 'N'), ('bora', 'N'), ('despedir', 'V'), ('do', 'KS'), ('Banzeiro', 'N')]]
#
#
# Caption:
# ...
#
#
# Comment:
# [[('Aonde', 'N'), ('fica', 'V'), ('@', 'N'), ('restaurantebanzeiro', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('edrienesoares', 'N'), ('fica', 'V'), ('na', 'PREP|+'), ('Rua', 'NPROP'), ('Libertador', 'N'), (',', ','), ('102', 'NUM'), (',', ','), ('Nossa', 'NPROP'), ('Senhora', 'NPROP'), ('das', 'NPROP'), ('Graças', 'NPROP')]]
#
#
# Caption:
# [[('Já', 'ADV'), ('experimentaram', 'N'), ('nossos', 'PROADJ'), ('Dadinhos', 'N'), ('de', 'PREP'), ('Tapioca', 'N'), ('?', '?')], [('#', 'N'), ('restaurantebanzeiro', 'N')]]
#
#
# Comment:
# [[('Olha', 'V'), ('@', 'N'), ('netoalmeida20', 'N')]]
#
#
# Caption:
# [[('Para', 'PREP'), ('comçar', 'N'), ('bem', 'ADV'), ('a', 'ART'), ('semana', 'N'), (',', ','), ('que', 'PRO-KS-REL'), ('tal', 'PROADJ'), ('almoçar', 'V'), ('no', 'PREP|+'), ('Banzeiro', 'N'), ('?', '?')]]
#
#
# Comment:
# [[('nossa', 'PROADJ'), ('mesa', 'N'), ('@', 'N'), ('thalitaaha', 'N'), ('@', 'N'), ('lourinha18gt', 'N')]]
#
#
# Comment:
# [[('Vamos', 'VAUX'), ('marcar', 'V'), ('nosso', 'PROADJ'), ('próximo', 'ADJ'), ('encontro', 'N'), ('no', 'PREP'), ('@', 'N'), ('restaurantebanzeiro', 'N'), ('amigas', 'N'), ('@', 'N'), ('thalitaaha', 'N'), ('@', 'N'), ('railcequintino', 'N'), ('😜', 'N')]]
#
#
# Caption:
# [[('Entrada', 'N'), ('triunfal', 'ADJ'), ('.', '.')]]
#
#
# Comment:
# [[('Fica', 'V'), ('próximo', 'PREP'), ('a', 'ART'), ('quê', 'PROSUB'), ('?', '?')], [('Onde', 'ADV'), ('?', '?')], [('Gostaria', 'V'), ('que', 'KS'), ('escrevesse', 'N'), ('aqui', 'ADV'), ('o', 'ART'), ('endereço', 'N'), ('completo', 'ADJ'), ('.', '.')], [('Assim', 'ADV'), (',', ','), ('eu', 'PROPESS'), ('coloco', 'V'), ('no', 'PREP|+'), ('GPS', 'NPROP'), ('.', 'NPROP')], [('Obrigada', 'PCP'), ('.', '.')]]
#
#
# Caption:
# [[('É', 'V'), ('com', 'PREP'), ('orgulho', 'N'), ('que', 'PRO-KS-REL'), ('anunciamos', 'N'), ('que', 'PRO-KS-REL'), ('o', 'ART'), ('nosso', 'PROADJ'), ('chef', 'N|EST'), (',', ','), ('Felipe', 'NPROP'), ('Schaedler', 'N'), ('está', 'V'), ('concorrendo', 'V'), ('ao', 'PREP'), ('prêmio', 'N'), ('``', 'N'), ('Melhores', 'NPROP'), ('do', 'NPROP'), ('Ano', 'NPROP'), ("''", 'N'), ('-', '-'), ('Prazeres', 'N'), ('da', 'N'), ('Mesa/Tramontina', 'N'), (',', ','), ('na', 'KS'), ('categoria', 'N'), ('``', 'N'), ('Revelação', 'NPROP'), ('do', 'NPROP'), ('Ano', 'NPROP'), ("''", 'N'), ('.', '.')], [('Você', 'PROPESS'), ('que', 'KS'), ('já', 'ADV'), ('prestigiou', 'N'), ('os', 'ART'), ('sabores', 'N'), ('inigualáveis', 'ADJ'), ('do', 'KS'), ('Banzeiro', 'N'), ('pode', 'VAUX'), ('votar', 'V'), ('nesta', 'N'), ('fera', 'ADJ'), ('da', 'NPROP'), ('gastronomia', 'N'), ('amazonense', 'N'), (',', ','), ('clicando', 'N'), ('aqui', 'ADV'), (':', ':'), ('http', 'N'), (':', ':'), ('//goo.gl/HxsEU6', 'N'), (';', ';'), (')', ')')]]
#
#
# Comment:
# [[('👏👏👏👏👏', 'N'), ('@', 'N'), ('rosejo1', 'N')]]
#
#
# Caption:
# [[('Presença', 'NPROP'), ('ilustre', 'ADJ'), ('!', '!')], [('A', 'ART'), ('queridíssima', 'N'), ('@', 'N'), ('fernandasouzaoficial', 'N'), ('tirou', 'V'), ('uma', 'ART'), ('folguinha', 'N'), ('da', 'N'), ('sua', 'PROADJ'), ('agenda', 'N'), ('ocupada', 'PCP'), ('para', 'PREP'), ('prestigiar', 'V'), ('o', 'ART'), ('menu', 'N|EST'), ('do', 'NPROP'), ('Banzeiro', 'N'), ('.', '.')], [('Sempre', 'ADV'), ('bem-vinda', 'PCP'), ('Fernanda', 'NPROP'), ('.', 'NPROP')]]
#
#
# Comment:
# [[('@', 'N'), ('kyviavidal', 'N'), ('até', 'PREP'), ('a', 'ART'), ('fernanda', 'N'), ('foi', 'VAUX'), ('!', '!'), ('!', '!'), ('!', '!')], [('!', '!'), ('tu', 'PROPESS'), ('tem', 'V'), ('que', 'KS'), ('ir', 'V'), ('!', '!'), ('!', '!'), ('!', '!')], [('!', '!'), ('😘😘', 'N')]]
#
#
# Comment:
# [[('Meninas', 'N'), ('olhem', 'N'), ('só', 'PDEN'), ('quem', 'PRO-KS'), ('foi', 'VAUX'), ('prestigiar', 'V'), ('o', 'ART'), ('Banzeiro', 'N'), ('hoje', 'ADV'), (':', ':'), (')', ')'), ('@', 'N'), ('erlamilene', 'N'), ('@', 'N'), ('myrellylarissa', 'N'), ('@', 'N'), ('milianepereira', 'N'), ('@', 'N'), ('sanndycorrea', 'N'), ('@', 'N'), ('brunawasen', 'N'), ('@', 'N'), ('glendacastro_', 'N'), ('@', 'N'), ('kassiia_souza', 'N'), ('@', 'N'), ('kjuliiana', 'N'), ('#', 'N'), ('meupassadonaomecondena', 'N'), ('#', 'N'), ('fernandasouza', 'N')]]
#
#
# Caption:
# [[('Você', 'PROPESS'), ('foi', 'VAUX'), ('CONVOCADO', 'N'), ('para', 'PREP'), ('viver', 'V'), ('essa', 'PROADJ'), ('experiência', 'N'), ('.', '.')], [('Venha', 'NPROP'), ('jantar', 'N'), ('no', 'PREP'), ('Banzeiro', 'N'), ('e', 'KC'), ('apreciar', 'V'), ('o', 'ART'), ('melhor', 'ADJ'), ('da', 'NPROP'), ('culinária', 'N'), ('regional', 'ADJ'), ('.', '.')]]
#
#
# Comment:
# [[(':', ':'), ('O', 'ART')]]
#
#
# Comment:
# [[('Vcs', 'N'), ('tem', 'V'), ('programação', 'N'), ('p', 'N'), ('almoço', 'N'), ('de', 'PREP'), ('amanhã', 'ADV'), ('?', '?'), ('!', '!')], [('@', 'N'), ('anacqueiroga', 'N'), ('@', 'N'), ('heliosimoes', 'N'), ('.', '.')], [('Banzeiro', 'N'), ('è👌', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('natalileal21', 'N'), ('Tô', 'VAUX'), ('por', 'PREP'), ('conta', 'N'), ('de', 'PREP'), ('vcs', 'N'), ('😎', 'N')]]
#
#
# Comment:
# [[('Égua', 'N'), ('agora', 'ADV'), ('eu', 'PROPESS'), ('me', 'PROPESS'), ('animei', 'N'), ('kkkkk', 'N'), ('.', '.')], [('Selado', 'PCP'), ('amanhã', 'ADV'), ('almoço', 'N'), (',', ','), ('café', 'N'), (',', ','), ('lanche', 'N'), ('da', 'N'), ('tarde', 'ADV'), ('e', 'KC'), ('jantar', 'N'), ('kkkkkkk', 'N'), ('@', 'N'), ('heliosimoes', 'N'), ('@', 'N'), ('anacqueiroga', 'N'), ('@', 'N'), ('rafael.monteiro.oliveira', 'N')]]
#
#
# Caption:
# [[('A', 'ART'), ('gastronomia', 'N'), ('regional', 'ADJ'), ('do', 'KS'), ('@', 'N'), ('restaurantebanzeiro', 'N'), ('é', 'V'), ('uma', 'ART'), ('coletânea', 'N'), ('de', 'PREP'), ('experiências', 'N'), ('vividas', 'PCP'), ('pelo', 'PDEN'), ('chef', 'N|EST'), ('@', 'N'), ('felipeschaedler_', 'N'), ('em', 'PREP|+'), ('suas', 'PROADJ'), ('viagens', 'N'), ('.', '.')], [('#', 'N'), ('instafood', 'N'), ('#', 'N'), ('food', 'N'), ('#', 'N'), ('amazonexperience', 'N')]]
#
#
# Comment:
# [[('👏🏻👏🏻👏🏻👏🏻', 'N')]]
#
#
# Caption:
# [[('Elaborado', 'PCP'), ('em', 'PREP|+'), ('safras', 'N'), ('excepcionais', 'ADJ'), (',', ','), ('Zavala', 'N'), ('foi', 'VAUX'), ('criado', 'PCP'), ('como', 'PREP'), ('um', 'ART'), ('presente', 'N'), ('aos', 'ADV'), ('amantes', 'N'), ('de', 'PREP'), ('bons', 'ADJ'), ('vinhos', 'N'), ('.', '.')], [('Um', 'ART'), ('brinde', 'N'), ('à', 'PREP|+'), ('sexta-feira', 'N'), ('!', '!')], [('🍷', 'N'), ('#', 'N'), ('fish', 'N|EST'), ('#', 'N'), ('instafood', 'N'), ('#', 'N'), ('tgif', 'N'), ('#', 'N'), ('sommelier', 'N')]]
#
#
# Comment:
# [[('Ótimo', 'ADJ'), ('vinho', 'N'), ('!', '!')]]
#
#
# Caption:
# [[('Presença', 'NPROP'), ('do', 'NPROP'), ('ilustre', 'ADJ'), ('chef', 'N|EST'), ('@', 'N'), ('alexatala', 'N'), ('prestigiando', 'N'), ('a', 'PREP|+'), ('cozinha', 'N'), ('regional', 'ADJ'), ('do', 'KS'), ('@', 'N'), ('restaurantebanzeiro', 'N'), ('#', 'N'), ('experienciaregional', 'N'), ('#', 'N'), ('fish', 'N|EST'), ('#', 'N'), ('manaus', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('restaurantebanzeiro', 'N'), ('foi', 'VAUX'), ('sensacional', 'ADJ'), ('!', '!'), ('!', '!'), ('!', '!')], [('!', '!'), ('da', 'NPROP'), ('próxima', 'ADJ'), ('vez', 'N'), ('que', 'PRO-KS-REL'), ('o', 'ART'), ('@', 'N'), ('alexatala', 'N'), ('estiver', 'V'), ('por', 'PREP'), ('aqui', 'ADV'), (',', ','), ('podemos', 'VAUX'), ('fazer', 'V'), ('a', 'ART'), ('sobremesa', 'ADJ'), ('do', 'KS'), ('jantar', 'N'), ('...', 'N'), ('.que', 'N'), ('tal', 'PROADJ'), ('@', 'N'), ('felipeshaedler_', 'N'), ('Seria', 'V'), ('uma', 'ART'), ('honra', 'N'), (':', ':'), (')', ')')]]
#
#
# Comment:
# [[('Poxa', 'N'), ('@', 'N'), ('alexatala', 'N'), (',', ','), ('dê', 'V'), ('uma', 'ART'), ('passada', 'PCP'), ('no', 'PREP|+'), ('nosso', 'PROADJ'), ('restaurante', 'N'), ('tbm', 'N'), ('...', 'N'), ('Apetit', 'N'), (',', ','), ('é', 'V'), ('simples', 'ADJ'), (',', ','), ('mais', 'ADV'), ('estamos', 'V'), ('fazendo', 'V'), ('com', 'PREP'), ('amor', 'N'), ('e', 'KC'), ('carinho', 'N'), ('...', 'N'), ('sou', 'VAUX'), ('seu', 'PROADJ'), ('fã', 'N'), ('.', '.')], [('Abraços', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('Poxa', 'N'), ('@', 'N'), ('alexatala', 'N'), (',', ','), ('dê', 'V'), ('uma', 'ART'), ('passada', 'PCP'), ('no', 'PREP|+'), ('nosso', 'PROADJ'), ('restaurante', 'N'), ('tbm', 'N'), ('...', 'N'), ('Apetit', 'N'), (',', ','), ('é', 'V'), ('simples', 'ADJ'), (',', ','), ('mais', 'ADV'), ('estamos', 'V'), ('fazendo', 'V'), ('com', 'PREP'), ('amor', 'N'), ('e', 'KC'), ('carinho', 'N'), ('...', 'N'), ('sou', 'VAUX'), ('seu', 'PROADJ'), ('fã', 'N'), ('.', '.')], [('Abraços', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('@', 'N'), ('onetyfilho74', 'N'), ('Numa', 'NPROP'), ('próxima', 'ADJ'), ('irei', 'N'), ('sim', 'ADV'), ('!', '!')], [('👊💢', 'N')]]
#
#
# Caption:
# [[('A', 'ART'), ('semana', 'N'), ('se', 'PROPESS'), ('inicia', 'V'), ('com', 'PREP'), ('bom', 'ADJ'), ('humor', 'N'), ('e', 'KC'), ('um', 'ART'), ('saboroso', 'ADJ'), ('Camarão', 'N'), ('com', 'PREP'), ('Catupiry', 'N'), ('.', '.')], [('#', 'N'), ('culinária', 'N'), ('#', 'N'), ('regional', 'ADJ'), ('#', 'N'), ('fish', 'N|EST'), ('#', 'N'), ('gourmet', 'N'), ('#', 'N'), ('travelerschoise', 'N'), ('#', 'N'), ('manaus', 'N'), ('#', 'N'), ('restaurantebanzeiro', 'N')]]
#
#
# Comment:
# [[('Vamos', 'VAUX'), ('sair', 'V'), ('por', 'PREP'), ('aí', 'ADV'), ('comendo', 'V'), ('o', 'ART'), ('mundo', 'N'), ('@', 'N'), ('heliosimoes', 'N'), ('@', 'N'), ('rafael.monteiro.oliveira', 'N'), ('@', 'N'), ('anacqueiroga', 'N'), ('😂😂😂', 'N')]]
#
#
# Comment:
# [[('@', 'N'), ('natalileal21', 'N'), ('HAHAHAHA', 'N'), ('😂😂😂😂😂😂', 'N')]]
#
#
# Comment:
# [[('Não', 'ADV'), ('foi', 'VAUX'), ('possível', 'ADJ'), ('ser', 'V'), ('eleito', 'PCP'), ('.', '.')], [('Só', 'PDEN'), ('tive', 'V'), ('476', 'N'), ('votos', 'N'), ('e', 'KC'), ('olha', 'V'), ('que', 'KS'), ('fiz', 'V'), ('um', 'ART'), ('excelente', 'ADJ'), ('trabalho', 'N'), (',', ','), ('no', 'KC'), ('qual', 'PRO-KS'), ('você', 'PROPESS'), ('ainda', 'ADV'), ('pode', 'VAUX'), ('conferir', 'V'), ('aqui..', 'N'), ('Obrigado', 'PCP'), ('por', 'PREP|+'), ('curtir', 'V'), ('as', 'ART'), ('minhas', 'PROADJ'), ('fotos', 'N'), ('ou', 'KC'), ('vê-las', 'N'), ('no', 'PREP'), ('seu', 'PROADJ'), ('feed', 'N'), ('.', '.')], [('Valeu', 'N'), ('por', 'PREP'), ('tudo', 'PROSUB'), ('e', 'KC'), ('vamos', 'VAUX'), ('em', 'PREP'), ('frente', 'PREP'), ('!', '!')]]
#
#
# Caption:
# [[('``', 'N'), ('Saboroso', 'N'), ("''", 'N'), (',', ','), ('``', 'N'), ('Melhor', 'ADJ'), ('peixaria', 'N'), ('gourmet', 'N'), ('de', 'PREP'), ('Manaus', 'NPROP'), ("''", 'N'), (',', ','), ('``', 'N'), ('Incrível', 'N'), ("''", 'N'), (',', ','), ('``', 'N'), ('Como', 'KS'), ('não', 'ADV'), ('se', 'PROPESS'), ('apaixonar', 'V'), ("''", 'N'), ('.', '.')], [('Algumas', 'PROADJ'), ('avaliações', 'N'), ('que', 'PRO-KS-REL'), ('fizeram', 'V'), ('o', 'ART'), ('@', 'N'), ('RestauranteBanzeiro', 'N'), ('vencedor', 'ADJ'), ('do', 'KS'), ('Travellers', 'N'), ('Choice', 'NPROP'), ('2013', 'N'), ('.', '.')], [('Já', 'ADV'), ('estamos', 'V'), ('preparados', 'PCP'), ('para', 'PREP'), ('este', 'PROADJ'), ('ano', 'N'), ('repetir', 'V'), ('a', 'ART'), ('dose', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('O', 'ART'), ('Programa', 'NPROP'), ('NaFesta', 'N'), ('da', 'N'), ('semana', 'N'), ('já', 'ADV'), ('foi', 'VAUX'), ('publicado', 'PCP'), (':', ':'), ('Entre', 'PREP'), ('no', 'KC'), ('nosso', 'PROADJ'), ('site', 'N'), (':', ':'), ('www.nafesta.com.br', 'N'), (',', ','), ('clique', 'N'), ('TvNaFesta', 'N'), ('e', 'KC'), ('cadastre-se', 'N'), ('no', 'PREP'), ('Canal', 'NPROP'), ('para', 'PREP'), ('assistir', 'V'), ('e', 'KC'), ('receber', 'V'), ('as', 'ART'), ('notificações', 'N'), ('...', 'N'), ('Vai', 'VAUX'), ('gostar', 'V'), ('muito', 'ADV'), ('dos', 'ADV'), ('programas', 'N'), ('já', 'ADV'), ('publicados', 'PCP'), ('...', '...')]]
#
#
# Caption:
# [[('Clima', 'N'), ('de', 'PREP'), ('chuva', 'N'), (',', ','), ('pede', 'V'), ('um', 'ART'), ('caldinho', 'N'), ('de', 'PREP'), ('peixe', 'N'), ('bem', 'ADV'), ('quente', 'ADJ'), ('.', '.')]]
#
#
# Comment:
# [[('Perfeito', 'NPROP')]]
#
#
# Caption:
# [[('Aqui', 'ADV'), (',', ','), ('a', 'ART'), ('noite', 'N'), ('começa', 'V'), ('com', 'PREP'), ('uma', 'ART'), ('boa', 'ADJ'), ('taça', 'N'), ('de', 'PREP'), ('vinho', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('Boa', 'ADJ'), ('pedida', 'N'), ('com', 'PREP'), ('esse', 'PROADJ'), ('tempinho', 'N'), ('!', '!'), ('!', '!')], [('!', '!')]]
#
#
# Caption:
# [[('Faça', 'V'), ('a', 'ART'), ('sua', 'PROADJ'), ('reserva', 'N'), ('para', 'PREP'), ('saborear', 'V'), ('o', 'ART'), ('melhor', 'ADJ'), ('da', 'NPROP'), ('gastronomia', 'N'), ('amazônica🍴📞', 'N'), ('(', '('), ('92', 'N'), (')', ')'), ('3234-1621/', 'N'), ('(', '('), ('92', 'N'), (')', ')'), ('8437-0274/', 'N'), ('(', '('), ('92', 'N'), (')', ')'), ('9204-7288', 'N'), ('.', '.')]]
#
#
# Caption:
# [[('Desbrave', 'N'), ('novos', 'ADJ'), ('sabores', 'N'), (',', ','), ('embale', 'N'), ('seu', 'PROADJ'), ('paladar', 'N'), ('e', 'KC'), ('descubra', 'N'), ('as', 'ART'), ('combinações', 'N'), ('de', 'PREP'), ('iguarias', 'N'), ('regionais', 'ADJ'), ('em', 'PREP|+'), ('nosso', 'PROADJ'), ('Menu', 'N|EST'), ('.', '.')], [('Aguardamos', 'V'), ('você', 'PROPESS'), ('.', '.')], [('🍴', 'N')]]
#
#
# Comment:
# [[('Estive', 'V'), ('no', 'PREP|+'), ('Banzeiro', 'N'), ('e', 'KC'), ('gostei', 'V'), ('muito', 'ADV'), ('!', '!'), ('!', '!'), ('!', '!')], [('Excelente👏👏', 'N')]]
#
#
# Comment:
# [[('Pensamento', 'NPROP'), ('da', 'NPROP'), ('semana', 'N'), ('...', 'N'), ('.', '.'), ("''", 'N'), ('A', 'ART'), ('vitalidade', 'N'), ('é', 'V'), ('demonstrada', 'PCP'), ('não', 'ADV'), ('apenas', 'PDEN'), ('pela', 'NPROP'), ('persistência', 'N'), (',', ','), ('mas', 'KC'), ('pela', 'NPROP'), ('capacidade', 'N'), ('de', 'PREP'), ('começar', 'V'), ('de', 'PREP'), ('novo', 'ADJ'), ('.', '.'), ("''", 'N')]]
#
#
# Caption:
# [[('Pastel', 'N'), ('de', 'PREP'), ('pato', 'N'), ('.', '.')], [('Deliciosamente', 'N'), ('incomparável', 'ADJ'), ('.', '.')], [('Uma', 'ART'), ('ótima', 'ADJ'), ('opção', 'N'), ('de', 'PREP'), ('entrada', 'N'), ('do', 'KS'), ('nosso', 'PROADJ'), ('menu', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('Eu', 'PROPESS'), ('amooooooooooooooo', 'N'), ('!', '!'), ('.', '.')]]
#
#
# Caption:
# [[('O', 'ART'), ('chef', 'N|EST'), ('Felipe', 'NPROP'), ('Schaedler', 'N'), ('foi', 'VAUX'), ('convidado', 'PCP'), ('para', 'PREP'), ('participar', 'V'), ('de', 'PREP'), ('um', 'ART'), ('programa', 'N'), ('que', 'PRO-KS-REL'), ('vai', 'VAUX'), ('percorrer', 'V'), ('o', 'ART'), ('Brasil', 'NPROP'), ('em', 'PREP|+'), ('uma', 'ART'), ('aventura', 'N'), ('gastronômica', 'ADJ'), (',', ','), ('desvendando', 'V'), ('a', 'ART'), ('cultura', 'N'), ('de', 'PREP'), ('cada', 'PROADJ'), ('cidade', 'N'), ('sede', 'N'), ('da', 'N'), ('Copa', 'NPROP'), ('do', 'NPROP'), ('Mundo', 'NPROP'), ('2014', 'N'), (',', ','), ('através', 'PREP|+'), ('da', 'NPROP'), ('culinária', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('@', 'N'), ('felipeschaedler_', 'N'), ('aqui', 'ADV'), ('kkkkk', 'N')]]
#
#
# Caption:
# [[('Totalmente', 'N'), ('diferente', 'ADJ'), ('de', 'PREP|+'), ('tudo', 'PROSUB'), ('o', 'ART'), ('que', 'PRO-KS-REL'), ('você', 'PROPESS'), ('já', 'ADV'), ('provou', 'V'), ('.', '.')], [('Experimente', 'V|+'), ('.', '.')]]
#
#
# Comment:
# [[('O', 'ART'), ('que', 'PRO-KS-REL'), ('é', 'V'), ('?', '?')]]
#
#
# Caption:
# [[('Petit', 'NPROP'), ('gateau', 'N'), ('amazônico', 'ADJ'), ('.', '.')], [('Venha', 'NPROP'), ('saborear', 'V'), ('essa', 'PROADJ'), ('mistura', 'N'), ('entre', 'PREP'), ('o', 'ART'), ('internacional', 'N'), ('e', 'KC'), ('o', 'ART'), ('regional', 'N'), ('.', '.')]]
#
#
# Comment:
# [[('@', 'N'), ('marinayumoto', 'N'), ('olha', 'V'), ('o', 'ART'), ('que', 'PRO-KS-REL'), ('eu', 'PROPESS'), ('te', 'PROPESS'), ('falei', 'V')]]
#
#
# Comment:
# [[('Murri', 'N'), ('@', 'N'), ('arthurcmiranda', 'N')]]
#
#
# Comment:
# [[('Perfeito👏🏻👏🏻', 'N')]]
